# %%
import torch
import torchvision.transforms as transforms
import torchvision
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
transform_train = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
])

# %%
trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform_train)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=100, shuffle=True, num_workers=2)
# Out:
# Files already downloaded and verified

# %%
class Generator(nn.Module):
    def __init__(self):
        super(Generator, self).__init__()
        self.fc1 = nn.Sequential(
            nn.Linear(110,768),
            nn.ReLU())
        self.tconv1 = nn.Sequential(
            nn.ConvTranspose2d(768, 384, 5, 2),
            nn.BatchNorm2d(384),
            nn.ReLU())
        self.tconv2 = nn.Sequential(
            nn.ConvTranspose2d(384, 192, 5, 2),
            nn.BatchNorm2d(192),
            nn.ReLU())
        self.tconv3 = nn.Sequential(
            nn.ConvTranspose2d(192, 96, 4, 2),
            nn.BatchNorm2d(96),
            nn.ReLU())
        self.tconv4 = nn.Sequential(
            nn.ConvTranspose2d(96, 48, 4, 1),
            nn.BatchNorm2d(48),
            nn.ReLU())
        self.tconv5 = nn.Sequential(
            nn.ConvTranspose2d(48, 3, 4, 2),
            nn.Tanh())
        self._initialize_weights()
    
    def forward(self, x):
        out = self.fc1(x)
        out = self.tconv1(out[:,:,None,None])
        out = self.tconv2(out)
        out = self.tconv3(out)
        out = self.tconv4(out)
        out = self.tconv5(out)
        return out
    
    def _initialize_weights(self):
        for m in self.modules():
            if isinstance(m, nn.ConvTranspose2d) or isinstance(m, nn.Linear):
                m.weight.data.normal_(0, 0.01)
                m.bias.data.zero_()
            elif isinstance(m, nn.BatchNorm2d):
                m.weight.data.fill_(1)
                m.bias.data.zero_()

# %%
class Discriminator(nn.Module):
    
    def __init__(self):
        super(Discriminator, self).__init__()
        self.upsample = nn.Upsample(scale_factor = 2)
        self.conv1 = nn.Sequential(
            nn.Conv2d(3, 16, 3, 2, 1),
            nn.LeakyReLU(0.2))
        self.conv2 = nn.Sequential(
            nn.Conv2d(16, 32, 3, 1, 1),
            nn.BatchNorm2d(32),
            nn.LeakyReLU(0.2))
        self.conv3 = nn.Sequential(
            nn.Conv2d(32, 64, 3, 2, 1),
            nn.BatchNorm2d(64),
            nn.LeakyReLU(0.2))
        self.conv4 = nn.Sequential(
            nn.Conv2d(64, 128, 3, 1, 1),
            nn.BatchNorm2d(128),
            nn.LeakyReLU(0.2))
        self.conv5 = nn.Sequential(
            nn.Conv2d(128, 256, 3, 2, 1),
            nn.BatchNorm2d(256),
            nn.LeakyReLU(0.2))
        self.conv6 = nn.Sequential(
            nn.Conv2d(256, 512, 3, 1, 1),
            nn.BatchNorm2d(512),
            nn.LeakyReLU(0.2))
        self.dropout = nn.Dropout(0.5)
        self.activation_noise_sd = 0.1
        self.fc = nn.Linear(8*8*512, 11)
        self.sigmoid = nn.Sigmoid()
        self.softmax = nn.Softmax(1)
        self._initialize_weights()

    def forward(self,x):
        if x.shape[-1] == 32:
            x = self.upsample(x)
        out = self.conv1(x)
        out = self.dropout(out + self.activation_noise_sd*torch.rand(out.shape).to(device))
        out = self.conv2(out)
        out = self.dropout(out + self.activation_noise_sd*torch.rand(out.shape).to(device))
        out = self.conv3(out)
        out = self.dropout(out + self.activation_noise_sd*torch.rand(out.shape).to(device))
        out = self.conv4(out)
        out = self.dropout(out + self.activation_noise_sd*torch.rand(out.shape).to(device))
        out = self.conv5(out)
        out = self.dropout(out + self.activation_noise_sd*torch.rand(out.shape).to(device))
        out = self.conv6(out)
        out = self.dropout(out + self.activation_noise_sd*torch.rand(out.shape).to(device))
        out = self.fc(out.reshape(-1,8*8*512))
        return self.sigmoid(out[:,0]), self.softmax(out[:,1:])
    
    def _initialize_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Conv2d) or isinstance(m, nn.Linear):
                m.weight.data.normal_(0, 0.01)
                m.bias.data.zero_()
            elif isinstance(m, nn.BatchNorm2d):
                m.weight.data.fill_(1)
                m.bias.data.zero_()

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
generator = Generator()
generator = generator.to(device)
discriminator = Discriminator()
discriminator = discriminator.to(device)

# %%
optimizer_d = optim.Adam(discriminator.parameters(), lr = 0.0002, betas = (0.5, 0.999))
optimizer_g = optim.Adam(generator.parameters(), lr = 0.0002, betas = (0.5, 0.999))
criterion_source = nn.BCELoss()
criterion_class = nn.NLLLoss()
print("We shall train for {} epochs".format(50000/len(trainloader)))
# Out:
# We shall train for 100.0 epochs

# %%
d_real_source_accuracies_avg = []
d_real_class_accuracies_avg = []
d_real_source_losses_avg = []
d_real_class_losses_avg = []
d_fake_source_accuracies_avg = []
d_fake_class_accuracies_avg = []
d_fake_source_losses_avg = []
d_fake_class_losses_avg = []
g_source_accuracies_avg = []
g_class_accuracies_avg = []
g_source_losses_avg = []
g_class_losses_avg = []

for epoch in range(100):
    print("Epoch {}:".format(epoch))
    
    d_real_source_accuracies = []
    d_real_class_accuracies = []
    d_real_source_losses = []
    d_real_class_losses = []
    d_fake_source_accuracies = []
    d_fake_class_accuracies = []
    d_fake_source_losses = []
    d_fake_class_losses = []
    g_source_accuracies = []
    g_class_accuracies = []
    g_source_losses = []
    g_class_losses = []
    
    for batch_idx, (inputs, targets) in enumerate(trainloader):
        if batch_idx % 100 == 0:
            print("Batch Index: {}".format(batch_idx))
        # Train discriminator with real data
        inputs, targets = inputs.to(device), targets.to(device)
        optimizer_d.zero_grad()
        sources, classes = discriminator(inputs)
        source_targets = torch.ones(sources.shape).to(device)
        source_loss = criterion_source(sources, source_targets)
        class_loss = 2*criterion_class(classes, targets)
        d_real_loss = (source_loss + class_loss)/2
        d_real_loss.backward()
        d_real_source_accuracy = torch.mean((torch.where(sources > 0.5, torch.tensor(1.).to(device), torch.tensor(0.).to(device)) == source_targets).float()).item()*100
        d_real_class_accuracy = torch.mean((classes.max(1)[1] == targets).float()).item()*100
        d_real_source_accuracies.append(d_real_source_accuracy)
        d_real_class_accuracies.append(d_real_class_accuracy)
        d_real_source_losses.append(source_loss.item())
        d_real_class_losses.append(class_loss.item())
        
        # Train discriminator with fake data
        fake_targets = np.random.randint(0, 10, inputs.shape[0])
        gen_input_np = np.c_[np.random.randn(inputs.shape[0], 100), np.eye(10)[fake_targets]]
        fake_targets = torch.from_numpy(fake_targets).long().to(device)
        gen_input = torch.from_numpy(gen_input_np).float().to(device)
        fake_inputs = generator(gen_input)
        sources, classes = discriminator(fake_inputs.detach())
        source_targets = torch.zeros(sources.shape).to(device)
        source_loss = criterion_source(sources, source_targets) 
        class_loss = criterion_class(classes, fake_targets)
        d_fake_loss = (source_loss + class_loss)/2
        d_fake_loss.backward()
        optimizer_d.step()
        d_fake_source_accuracy = np.round(torch.mean((torch.where(sources > 0.5, torch.tensor(1.).to(device), torch.tensor(0.).to(device)) == source_targets).float()).item()*100)
        d_fake_class_accuracy = np.round(torch.mean((classes.max(1)[1] == fake_targets).float()).item()*100)
        d_fake_source_accuracies.append(d_fake_source_accuracy)
        d_fake_class_accuracies.append(d_fake_class_accuracy)
        d_fake_source_losses.append(source_loss.item())
        d_fake_class_losses.append(class_loss.item())
        
        # Train generator
        optimizer_g.zero_grad()
        sources, classes = discriminator(fake_inputs)
        source_targets = torch.ones(sources.shape).to(device)
        source_loss = criterion_source(sources, source_targets) 
        class_loss = criterion_class(classes, fake_targets)
        g_loss = source_loss + class_loss
        g_loss.backward()
        optimizer_g.step()
        g_source_accuracy = np.round(torch.mean((torch.where(sources > 0.5, torch.tensor(1.).to(device), torch.tensor(0.).to(device)) == source_targets).float()).item()*100)
        g_class_accuracy = np.round(torch.mean((classes.max(1)[1] == fake_targets).float()).item()*100)
        g_source_accuracies.append(g_source_accuracy)
        g_class_accuracies.append(g_class_accuracy)
        g_source_losses.append(source_loss.item())
        g_class_losses.append(class_loss.item())

    torch.save(generator.state_dict(), "generator100_large.pt")
    torch.save(discriminator.state_dict(), "discriminator100_large.pt")

    print("Discriminator source accuracy and loss on real data is {:.2f}% and {:.3f}.".format(np.mean(d_real_source_accuracies), np.mean(d_real_source_losses)))
    print("Discriminator class accuracy and loss on real data is {:.2f}% and {:.3f}.".format(np.mean(d_real_class_accuracies), np.mean(d_real_class_losses)))
    print("Discriminator source accuracy and loss on fake data is {:.2f}% and {:.3f}.".format(np.mean(d_fake_source_accuracies), np.mean(d_fake_source_losses)))
    print("Discriminator class accuracy and loss on fake data is {:.2f}% and {:.3f}.".format(np.mean(d_fake_class_accuracies), np.mean(d_fake_class_losses)))
    print("Generator source accuracy and loss is {:.2f}% and {:.3f}.".format(np.mean(g_source_accuracies), np.mean(g_source_losses)))
    print("Generator class accuracy and loss is {:.2f}% and {:.3f}.\n".format(np.mean(g_class_accuracies), np.mean(g_class_losses)))
    
    d_real_source_accuracies_avg.append(np.mean(d_real_source_accuracies))
    d_real_class_accuracies_avg.append(np.mean(d_real_class_accuracies))
    d_real_source_losses_avg.append(np.mean(d_real_source_losses))
    d_real_class_losses_avg.append(np.mean(d_real_class_losses))
    d_fake_source_accuracies_avg.append(np.mean(d_fake_source_accuracies))
    d_fake_class_accuracies_avg.append(np.mean(d_fake_class_accuracies))
    d_fake_source_losses_avg.append(np.mean(d_fake_source_losses))
    d_fake_class_losses_avg.append(np.mean(d_fake_class_losses))
    g_source_accuracies_avg.append(np.mean(g_source_accuracies))
    g_class_accuracies_avg.append(np.mean(g_class_accuracies))
    g_source_losses_avg.append(np.mean(g_source_losses))
    g_class_losses_avg.append(np.mean(g_class_losses))
# Out:
# Epoch 0:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 55.97% and 1.001.
# Discriminator class accuracy and loss on real data is 16.79% and -0.332.
# Discriminator source accuracy and loss on fake data is 56.61% and 0.878.
# Discriminator class accuracy and loss on fake data is 11.01% and -0.110.
# Generator source accuracy and loss is 27.10% and 1.827.
# Generator class accuracy and loss is 11.24% and -0.112.
#
# Epoch 1:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 66.05% and 0.769.
# Discriminator class accuracy and loss on real data is 20.57% and -0.409.
# Discriminator source accuracy and loss on fake data is 68.16% and 0.637.
# Discriminator class accuracy and loss on fake data is 11.67% and -0.117.
# Generator source accuracy and loss is 9.79% and 2.216.
# Generator class accuracy and loss is 12.10% and -0.121.
#
# Epoch 2:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 72.86% and 0.621.
# Discriminator class accuracy and loss on real data is 24.05% and -0.479.
# Discriminator source accuracy and loss on fake data is 75.99% and 0.499.
# Discriminator class accuracy and loss on fake data is 11.02% and -0.110.
# Generator source accuracy and loss is 5.78% and 2.828.
# Generator class accuracy and loss is 11.36% and -0.113.
#
# Epoch 3:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 77.75% and 0.528.
# Discriminator class accuracy and loss on real data is 23.71% and -0.474.
# Discriminator source accuracy and loss on fake data is 80.61% and 0.431.
# Discriminator class accuracy and loss on fake data is 11.69% and -0.117.
# Generator source accuracy and loss is 5.52% and 3.098.
# Generator class accuracy and loss is 11.80% and -0.118.
#
# Epoch 4:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 79.38% and 0.500.
# Discriminator class accuracy and loss on real data is 26.06% and -0.519.
# Discriminator source accuracy and loss on fake data is 82.29% and 0.398.
# Discriminator class accuracy and loss on fake data is 12.05% and -0.121.
# Generator source accuracy and loss is 3.09% and 3.636.
# Generator class accuracy and loss is 12.37% and -0.123.
#
# Epoch 5:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 80.00% and 0.498.
# Discriminator class accuracy and loss on real data is 27.25% and -0.543.
# Discriminator source accuracy and loss on fake data is 82.64% and 0.397.
# Discriminator class accuracy and loss on fake data is 12.34% and -0.123.
# Generator source accuracy and loss is 3.11% and 4.069.
# Generator class accuracy and loss is 12.64% and -0.126.
#
# Epoch 6:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 78.60% and 0.512.
# Discriminator class accuracy and loss on real data is 28.94% and -0.576.
# Discriminator source accuracy and loss on fake data is 80.86% and 0.428.
# Discriminator class accuracy and loss on fake data is 10.79% and -0.108.
# Generator source accuracy and loss is 5.55% and 3.638.
# Generator class accuracy and loss is 11.22% and -0.112.
#
# Epoch 7:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 73.86% and 0.585.
# Discriminator class accuracy and loss on real data is 30.81% and -0.615.
# Discriminator source accuracy and loss on fake data is 76.21% and 0.509.
# Discriminator class accuracy and loss on fake data is 10.51% and -0.105.
# Generator source accuracy and loss is 8.22% and 2.793.
# Generator class accuracy and loss is 10.75% and -0.107.
#
# Epoch 8:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 77.41% and 0.519.
# Discriminator class accuracy and loss on real data is 32.27% and -0.643.
# Discriminator source accuracy and loss on fake data is 79.90% and 0.438.
# Discriminator class accuracy and loss on fake data is 11.42% and -0.114.
# Generator source accuracy and loss is 5.90% and 3.161.
# Generator class accuracy and loss is 11.64% and -0.116.
#
# Epoch 9:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 73.84% and 0.580.
# Discriminator class accuracy and loss on real data is 32.09% and -0.639.
# Discriminator source accuracy and loss on fake data is 76.17% and 0.506.
# Discriminator class accuracy and loss on fake data is 11.13% and -0.111.
# Generator source accuracy and loss is 7.84% and 2.732.
# Generator class accuracy and loss is 11.43% and -0.114.
#
# Epoch 10:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 76.73% and 0.526.
# Discriminator class accuracy and loss on real data is 32.88% and -0.657.
# Discriminator source accuracy and loss on fake data is 78.76% and 0.462.
# Discriminator class accuracy and loss on fake data is 11.01% and -0.110.
# Generator source accuracy and loss is 6.41% and 3.036.
# Generator class accuracy and loss is 11.26% and -0.112.
#
# Epoch 11:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 75.72% and 0.539.
# Discriminator class accuracy and loss on real data is 33.98% and -0.678.
# Discriminator source accuracy and loss on fake data is 77.78% and 0.475.
# Discriminator class accuracy and loss on fake data is 11.76% and -0.118.
# Generator source accuracy and loss is 7.45% and 2.848.
# Generator class accuracy and loss is 11.83% and -0.118.
#
# Epoch 12:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 72.74% and 0.582.
# Discriminator class accuracy and loss on real data is 34.81% and -0.695.
# Discriminator source accuracy and loss on fake data is 74.52% and 0.529.
# Discriminator class accuracy and loss on fake data is 11.75% and -0.117.
# Generator source accuracy and loss is 10.50% and 2.448.
# Generator class accuracy and loss is 12.04% and -0.120.
#
# Epoch 13:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 73.12% and 0.568.
# Discriminator class accuracy and loss on real data is 35.51% and -0.707.
# Discriminator source accuracy and loss on fake data is 75.17% and 0.517.
# Discriminator class accuracy and loss on fake data is 12.22% and -0.122.
# Generator source accuracy and loss is 9.32% and 2.500.
# Generator class accuracy and loss is 12.55% and -0.125.
#
# Epoch 14:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 72.95% and 0.567.
# Discriminator class accuracy and loss on real data is 35.78% and -0.714.
# Discriminator source accuracy and loss on fake data is 75.02% and 0.521.
# Discriminator class accuracy and loss on fake data is 12.60% and -0.126.
# Generator source accuracy and loss is 10.33% and 2.385.
# Generator class accuracy and loss is 12.82% and -0.128.
#
# Epoch 15:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 72.07% and 0.581.
# Discriminator class accuracy and loss on real data is 36.55% and -0.729.
# Discriminator source accuracy and loss on fake data is 73.86% and 0.536.
# Discriminator class accuracy and loss on fake data is 13.03% and -0.130.
# Generator source accuracy and loss is 10.81% and 2.337.
# Generator class accuracy and loss is 13.13% and -0.131.
#
# Epoch 16:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 72.54% and 0.573.
# Discriminator class accuracy and loss on real data is 39.64% and -0.789.
# Discriminator source accuracy and loss on fake data is 74.50% and 0.523.
# Discriminator class accuracy and loss on fake data is 14.86% and -0.148.
# Generator source accuracy and loss is 10.64% and 2.299.
# Generator class accuracy and loss is 14.89% and -0.149.
#
# Epoch 17:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 72.91% and 0.571.
# Discriminator class accuracy and loss on real data is 40.69% and -0.811.
# Discriminator source accuracy and loss on fake data is 74.59% and 0.525.
# Discriminator class accuracy and loss on fake data is 15.69% and -0.157.
# Generator source accuracy and loss is 10.92% and 2.323.
# Generator class accuracy and loss is 15.79% and -0.158.
#
# Epoch 18:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 70.22% and 0.603.
# Discriminator class accuracy and loss on real data is 41.66% and -0.828.
# Discriminator source accuracy and loss on fake data is 71.50% and 0.567.
# Discriminator class accuracy and loss on fake data is 17.15% and -0.171.
# Generator source accuracy and loss is 14.47% and 1.959.
# Generator class accuracy and loss is 17.39% and -0.174.
#
# Epoch 19:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 70.96% and 0.580.
# Discriminator class accuracy and loss on real data is 41.83% and -0.833.
# Discriminator source accuracy and loss on fake data is 72.89% and 0.543.
# Discriminator class accuracy and loss on fake data is 17.80% and -0.178.
# Generator source accuracy and loss is 13.49% and 2.013.
# Generator class accuracy and loss is 17.91% and -0.179.
#
# Epoch 20:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 70.89% and 0.586.
# Discriminator class accuracy and loss on real data is 42.30% and -0.843.
# Discriminator source accuracy and loss on fake data is 72.35% and 0.556.
# Discriminator class accuracy and loss on fake data is 21.52% and -0.215.
# Generator source accuracy and loss is 14.56% and 1.962.
# Generator class accuracy and loss is 21.85% and -0.218.
#
# Epoch 21:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 69.27% and 0.610.
# Discriminator class accuracy and loss on real data is 42.91% and -0.857.
# Discriminator source accuracy and loss on fake data is 70.64% and 0.578.
# Discriminator class accuracy and loss on fake data is 23.56% and -0.236.
# Generator source accuracy and loss is 16.12% and 1.856.
# Generator class accuracy and loss is 23.71% and -0.236.
#
# Epoch 22:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 70.09% and 0.590.
# Discriminator class accuracy and loss on real data is 43.28% and -0.863.
# Discriminator source accuracy and loss on fake data is 71.63% and 0.560.
# Discriminator class accuracy and loss on fake data is 26.92% and -0.269.
# Generator source accuracy and loss is 15.97% and 1.797.
# Generator class accuracy and loss is 27.41% and -0.274.
#
# Epoch 23:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 69.38% and 0.599.
# Discriminator class accuracy and loss on real data is 43.94% and -0.877.
# Discriminator source accuracy and loss on fake data is 70.82% and 0.577.
# Discriminator class accuracy and loss on fake data is 32.66% and -0.326.
# Generator source accuracy and loss is 16.66% and 1.767.
# Generator class accuracy and loss is 33.16% and -0.331.
#
# Epoch 24:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 69.50% and 0.600.
# Discriminator class accuracy and loss on real data is 44.13% and -0.881.
# Discriminator source accuracy and loss on fake data is 70.23% and 0.580.
# Discriminator class accuracy and loss on fake data is 41.16% and -0.411.
# Generator source accuracy and loss is 18.21% and 1.689.
# Generator class accuracy and loss is 41.84% and -0.417.
#
# Epoch 25:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 68.51% and 0.608.
# Discriminator class accuracy and loss on real data is 44.27% and -0.883.
# Discriminator source accuracy and loss on fake data is 69.67% and 0.586.
# Discriminator class accuracy and loss on fake data is 52.18% and -0.521.
# Generator source accuracy and loss is 18.50% and 1.660.
# Generator class accuracy and loss is 52.43% and -0.523.
#
# Epoch 26:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 68.38% and 0.608.
# Discriminator class accuracy and loss on real data is 44.90% and -0.895.
# Discriminator source accuracy and loss on fake data is 69.46% and 0.591.
# Discriminator class accuracy and loss on fake data is 58.69% and -0.586.
# Generator source accuracy and loss is 19.65% and 1.592.
# Generator class accuracy and loss is 59.01% and -0.589.
#
# Epoch 27:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 67.87% and 0.609.
# Discriminator class accuracy and loss on real data is 46.15% and -0.921.
# Discriminator source accuracy and loss on fake data is 68.85% and 0.596.
# Discriminator class accuracy and loss on fake data is 62.55% and -0.624.
# Generator source accuracy and loss is 19.88% and 1.537.
# Generator class accuracy and loss is 62.76% and -0.627.
#
# Epoch 28:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 68.25% and 0.608.
# Discriminator class accuracy and loss on real data is 48.93% and -0.975.
# Discriminator source accuracy and loss on fake data is 69.08% and 0.592.
# Discriminator class accuracy and loss on fake data is 65.94% and -0.658.
# Generator source accuracy and loss is 19.58% and 1.567.
# Generator class accuracy and loss is 66.17% and -0.660.
#
# Epoch 29:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 67.66% and 0.614.
# Discriminator class accuracy and loss on real data is 50.17% and -1.001.
# Discriminator source accuracy and loss on fake data is 68.87% and 0.596.
# Discriminator class accuracy and loss on fake data is 69.24% and -0.691.
# Generator source accuracy and loss is 21.11% and 1.505.
# Generator class accuracy and loss is 69.59% and -0.695.
#
# Epoch 30:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 67.46% and 0.615.
# Discriminator class accuracy and loss on real data is 50.79% and -1.012.
# Discriminator source accuracy and loss on fake data is 68.42% and 0.599.
# Discriminator class accuracy and loss on fake data is 71.67% and -0.715.
# Generator source accuracy and loss is 21.12% and 1.527.
# Generator class accuracy and loss is 71.91% and -0.718.
#
# Epoch 31:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 66.74% and 0.623.
# Discriminator class accuracy and loss on real data is 51.47% and -1.026.
# Discriminator source accuracy and loss on fake data is 67.08% and 0.611.
# Discriminator class accuracy and loss on fake data is 74.79% and -0.746.
# Generator source accuracy and loss is 23.09% and 1.411.
# Generator class accuracy and loss is 75.01% and -0.749.
#
# Epoch 32:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 66.76% and 0.622.
# Discriminator class accuracy and loss on real data is 52.08% and -1.039.
# Discriminator source accuracy and loss on fake data is 67.54% and 0.608.
# Discriminator class accuracy and loss on fake data is 75.70% and -0.756.
# Generator source accuracy and loss is 23.45% and 1.392.
# Generator class accuracy and loss is 75.97% and -0.758.
#
# Epoch 33:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 65.87% and 0.631.
# Discriminator class accuracy and loss on real data is 52.90% and -1.054.
# Discriminator source accuracy and loss on fake data is 66.94% and 0.617.
# Discriminator class accuracy and loss on fake data is 76.02% and -0.759.
# Generator source accuracy and loss is 24.30% and 1.363.
# Generator class accuracy and loss is 76.26% and -0.762.
#
# Epoch 34:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 66.51% and 0.622.
# Discriminator class accuracy and loss on real data is 53.29% and -1.063.
# Discriminator source accuracy and loss on fake data is 67.48% and 0.611.
# Discriminator class accuracy and loss on fake data is 75.97% and -0.759.
# Generator source accuracy and loss is 22.67% and 1.399.
# Generator class accuracy and loss is 76.31% and -0.762.
#
# Epoch 35:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 67.02% and 0.617.
# Discriminator class accuracy and loss on real data is 53.58% and -1.070.
# Discriminator source accuracy and loss on fake data is 67.96% and 0.605.
# Discriminator class accuracy and loss on fake data is 76.51% and -0.764.
# Generator source accuracy and loss is 22.14% and 1.418.
# Generator class accuracy and loss is 76.84% and -0.767.
#
# Epoch 36:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 66.51% and 0.623.
# Discriminator class accuracy and loss on real data is 54.11% and -1.079.
# Discriminator source accuracy and loss on fake data is 67.48% and 0.611.
# Discriminator class accuracy and loss on fake data is 76.97% and -0.768.
# Generator source accuracy and loss is 23.38% and 1.376.
# Generator class accuracy and loss is 77.27% and -0.772.
#
# Epoch 37:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 66.33% and 0.627.
# Discriminator class accuracy and loss on real data is 54.44% and -1.086.
# Discriminator source accuracy and loss on fake data is 66.90% and 0.616.
# Discriminator class accuracy and loss on fake data is 76.58% and -0.765.
# Generator source accuracy and loss is 23.71% and 1.362.
# Generator class accuracy and loss is 76.78% and -0.767.
#
# Epoch 38:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 66.47% and 0.622.
# Discriminator class accuracy and loss on real data is 54.80% and -1.094.
# Discriminator source accuracy and loss on fake data is 67.25% and 0.611.
# Discriminator class accuracy and loss on fake data is 77.65% and -0.775.
# Generator source accuracy and loss is 23.51% and 1.360.
# Generator class accuracy and loss is 77.63% and -0.775.
#
# Epoch 39:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 66.17% and 0.629.
# Discriminator class accuracy and loss on real data is 55.09% and -1.099.
# Discriminator source accuracy and loss on fake data is 66.76% and 0.618.
# Discriminator class accuracy and loss on fake data is 77.26% and -0.772.
# Generator source accuracy and loss is 23.89% and 1.344.
# Generator class accuracy and loss is 77.40% and -0.773.
#
# Epoch 40:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 66.07% and 0.631.
# Discriminator class accuracy and loss on real data is 55.27% and -1.103.
# Discriminator source accuracy and loss on fake data is 66.89% and 0.615.
# Discriminator class accuracy and loss on fake data is 77.03% and -0.769.
# Generator source accuracy and loss is 25.00% and 1.309.
# Generator class accuracy and loss is 77.21% and -0.771.
#
# Epoch 41:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 65.91% and 0.630.
# Discriminator class accuracy and loss on real data is 55.29% and -1.103.
# Discriminator source accuracy and loss on fake data is 66.77% and 0.615.
# Discriminator class accuracy and loss on fake data is 77.41% and -0.773.
# Generator source accuracy and loss is 24.68% and 1.298.
# Generator class accuracy and loss is 77.61% and -0.775.
#
# Epoch 42:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 66.29% and 0.626.
# Discriminator class accuracy and loss on real data is 55.63% and -1.109.
# Discriminator source accuracy and loss on fake data is 66.94% and 0.612.
# Discriminator class accuracy and loss on fake data is 76.80% and -0.767.
# Generator source accuracy and loss is 23.21% and 1.353.
# Generator class accuracy and loss is 76.99% and -0.769.
#
# Epoch 43:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 66.52% and 0.624.
# Discriminator class accuracy and loss on real data is 55.97% and -1.116.
# Discriminator source accuracy and loss on fake data is 67.22% and 0.612.
# Discriminator class accuracy and loss on fake data is 81.69% and -0.815.
# Generator source accuracy and loss is 24.27% and 1.316.
# Generator class accuracy and loss is 81.90% and -0.818.
#
# Epoch 44:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 65.74% and 0.630.
# Discriminator class accuracy and loss on real data is 57.55% and -1.147.
# Discriminator source accuracy and loss on fake data is 66.51% and 0.618.
# Discriminator class accuracy and loss on fake data is 84.65% and -0.845.
# Generator source accuracy and loss is 25.84% and 1.275.
# Generator class accuracy and loss is 85.01% and -0.848.
#
# Epoch 45:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 66.11% and 0.624.
# Discriminator class accuracy and loss on real data is 58.01% and -1.156.
# Discriminator source accuracy and loss on fake data is 66.89% and 0.612.
# Discriminator class accuracy and loss on fake data is 85.36% and -0.852.
# Generator source accuracy and loss is 25.24% and 1.278.
# Generator class accuracy and loss is 85.69% and -0.856.
#
# Epoch 46:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 65.77% and 0.631.
# Discriminator class accuracy and loss on real data is 58.54% and -1.166.
# Discriminator source accuracy and loss on fake data is 66.48% and 0.617.
# Discriminator class accuracy and loss on fake data is 85.79% and -0.856.
# Generator source accuracy and loss is 25.22% and 1.287.
# Generator class accuracy and loss is 85.96% and -0.858.
#
# Epoch 47:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 65.93% and 0.630.
# Discriminator class accuracy and loss on real data is 58.99% and -1.176.
# Discriminator source accuracy and loss on fake data is 66.60% and 0.618.
# Discriminator class accuracy and loss on fake data is 86.15% and -0.859.
# Generator source accuracy and loss is 24.98% and 1.277.
# Generator class accuracy and loss is 86.34% and -0.861.
#
# Epoch 48:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 65.59% and 0.631.
# Discriminator class accuracy and loss on real data is 59.10% and -1.178.
# Discriminator source accuracy and loss on fake data is 66.67% and 0.615.
# Discriminator class accuracy and loss on fake data is 86.03% and -0.858.
# Generator source accuracy and loss is 25.22% and 1.281.
# Generator class accuracy and loss is 86.22% and -0.861.
#
# Epoch 49:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 65.00% and 0.638.
# Discriminator class accuracy and loss on real data is 59.72% and -1.191.
# Discriminator source accuracy and loss on fake data is 65.99% and 0.625.
# Discriminator class accuracy and loss on fake data is 86.32% and -0.861.
# Generator source accuracy and loss is 25.99% and 1.260.
# Generator class accuracy and loss is 86.49% and -0.863.
#
# Epoch 50:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 66.02% and 0.624.
# Discriminator class accuracy and loss on real data is 60.06% and -1.197.
# Discriminator source accuracy and loss on fake data is 66.91% and 0.613.
# Discriminator class accuracy and loss on fake data is 88.61% and -0.884.
# Generator source accuracy and loss is 24.52% and 1.290.
# Generator class accuracy and loss is 88.86% and -0.887.
#
# Epoch 51:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 65.94% and 0.626.
# Discriminator class accuracy and loss on real data is 60.90% and -1.215.
# Discriminator source accuracy and loss on fake data is 66.83% and 0.612.
# Discriminator class accuracy and loss on fake data is 94.27% and -0.941.
# Generator source accuracy and loss is 24.87% and 1.272.
# Generator class accuracy and loss is 94.62% and -0.944.
#
# Epoch 52:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 66.09% and 0.625.
# Discriminator class accuracy and loss on real data is 61.23% and -1.221.
# Discriminator source accuracy and loss on fake data is 66.95% and 0.613.
# Discriminator class accuracy and loss on fake data is 95.04% and -0.948.
# Generator source accuracy and loss is 24.83% and 1.296.
# Generator class accuracy and loss is 95.32% and -0.951.
#
# Epoch 53:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 66.57% and 0.622.
# Discriminator class accuracy and loss on real data is 61.63% and -1.228.
# Discriminator source accuracy and loss on fake data is 67.35% and 0.608.
# Discriminator class accuracy and loss on fake data is 95.85% and -0.956.
# Generator source accuracy and loss is 24.08% and 1.300.
# Generator class accuracy and loss is 96.08% and -0.958.
#
# Epoch 54:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 65.38% and 0.634.
# Discriminator class accuracy and loss on real data is 62.06% and -1.237.
# Discriminator source accuracy and loss on fake data is 66.46% and 0.621.
# Discriminator class accuracy and loss on fake data is 96.00% and -0.958.
# Generator source accuracy and loss is 25.32% and 1.274.
# Generator class accuracy and loss is 96.35% and -0.961.
#
# Epoch 55:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 66.14% and 0.623.
# Discriminator class accuracy and loss on real data is 62.22% and -1.241.
# Discriminator source accuracy and loss on fake data is 67.01% and 0.611.
# Discriminator class accuracy and loss on fake data is 96.03% and -0.958.
# Generator source accuracy and loss is 24.23% and 1.301.
# Generator class accuracy and loss is 96.21% and -0.960.
#
# Epoch 56:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 66.46% and 0.621.
# Discriminator class accuracy and loss on real data is 62.85% and -1.251.
# Discriminator source accuracy and loss on fake data is 67.31% and 0.607.
# Discriminator class accuracy and loss on fake data is 96.06% and -0.958.
# Generator source accuracy and loss is 24.87% and 1.276.
# Generator class accuracy and loss is 96.41% and -0.962.
#
# Epoch 57:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 66.06% and 0.626.
# Discriminator class accuracy and loss on real data is 63.44% and -1.262.
# Discriminator source accuracy and loss on fake data is 67.03% and 0.611.
# Discriminator class accuracy and loss on fake data is 96.69% and -0.965.
# Generator source accuracy and loss is 23.48% and 1.313.
# Generator class accuracy and loss is 96.95% and -0.967.
#
# Epoch 58:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 66.32% and 0.623.
# Discriminator class accuracy and loss on real data is 63.40% and -1.263.
# Discriminator source accuracy and loss on fake data is 67.52% and 0.607.
# Discriminator class accuracy and loss on fake data is 96.54% and -0.963.
# Generator source accuracy and loss is 24.24% and 1.294.
# Generator class accuracy and loss is 96.90% and -0.966.
#
# Epoch 59:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 66.12% and 0.624.
# Discriminator class accuracy and loss on real data is 63.36% and -1.260.
# Discriminator source accuracy and loss on fake data is 67.03% and 0.609.
# Discriminator class accuracy and loss on fake data is 96.11% and -0.958.
# Generator source accuracy and loss is 25.42% and 1.268.
# Generator class accuracy and loss is 96.51% and -0.963.
#
# Epoch 60:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 66.43% and 0.621.
# Discriminator class accuracy and loss on real data is 63.43% and -1.264.
# Discriminator source accuracy and loss on fake data is 67.21% and 0.608.
# Discriminator class accuracy and loss on fake data is 96.38% and -0.961.
# Generator source accuracy and loss is 25.26% and 1.266.
# Generator class accuracy and loss is 96.64% and -0.964.
#
# Epoch 61:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 65.94% and 0.627.
# Discriminator class accuracy and loss on real data is 63.62% and -1.267.
# Discriminator source accuracy and loss on fake data is 67.02% and 0.614.
# Discriminator class accuracy and loss on fake data is 96.73% and -0.965.
# Generator source accuracy and loss is 24.98% and 1.287.
# Generator class accuracy and loss is 97.05% and -0.969.
#
# Epoch 62:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 67.69% and 0.608.
# Discriminator class accuracy and loss on real data is 63.81% and -1.271.
# Discriminator source accuracy and loss on fake data is 68.64% and 0.591.
# Discriminator class accuracy and loss on fake data is 96.45% and -0.962.
# Generator source accuracy and loss is 23.58% and 1.317.
# Generator class accuracy and loss is 96.72% and -0.965.
#
# Epoch 63:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 66.98% and 0.616.
# Discriminator class accuracy and loss on real data is 63.94% and -1.274.
# Discriminator source accuracy and loss on fake data is 67.90% and 0.602.
# Discriminator class accuracy and loss on fake data is 96.57% and -0.963.
# Generator source accuracy and loss is 24.06% and 1.318.
# Generator class accuracy and loss is 96.85% and -0.966.
#
# Epoch 64:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 65.45% and 0.635.
# Discriminator class accuracy and loss on real data is 64.09% and -1.278.
# Discriminator source accuracy and loss on fake data is 65.92% and 0.622.
# Discriminator class accuracy and loss on fake data is 96.45% and -0.962.
# Generator source accuracy and loss is 25.78% and 1.253.
# Generator class accuracy and loss is 96.78% and -0.965.
#
# Epoch 65:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 65.86% and 0.626.
# Discriminator class accuracy and loss on real data is 64.45% and -1.284.
# Discriminator source accuracy and loss on fake data is 66.54% and 0.616.
# Discriminator class accuracy and loss on fake data is 96.45% and -0.962.
# Generator source accuracy and loss is 26.27% and 1.231.
# Generator class accuracy and loss is 96.84% and -0.966.
#
# Epoch 66:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 66.32% and 0.619.
# Discriminator class accuracy and loss on real data is 64.83% and -1.292.
# Discriminator source accuracy and loss on fake data is 67.15% and 0.607.
# Discriminator class accuracy and loss on fake data is 96.80% and -0.966.
# Generator source accuracy and loss is 25.61% and 1.245.
# Generator class accuracy and loss is 96.96% and -0.968.
#
# Epoch 67:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 67.35% and 0.611.
# Discriminator class accuracy and loss on real data is 64.55% and -1.286.
# Discriminator source accuracy and loss on fake data is 68.29% and 0.594.
# Discriminator class accuracy and loss on fake data is 96.50% and -0.963.
# Generator source accuracy and loss is 22.11% and 1.362.
# Generator class accuracy and loss is 96.82% and -0.966.
#
# Epoch 68:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 66.01% and 0.623.
# Discriminator class accuracy and loss on real data is 64.85% and -1.292.
# Discriminator source accuracy and loss on fake data is 66.93% and 0.610.
# Discriminator class accuracy and loss on fake data is 97.22% and -0.970.
# Generator source accuracy and loss is 25.24% and 1.268.
# Generator class accuracy and loss is 97.38% and -0.972.
#
# Epoch 69:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 66.72% and 0.616.
# Discriminator class accuracy and loss on real data is 65.06% and -1.296.
# Discriminator source accuracy and loss on fake data is 68.07% and 0.601.
# Discriminator class accuracy and loss on fake data is 96.54% and -0.963.
# Generator source accuracy and loss is 24.48% and 1.279.
# Generator class accuracy and loss is 96.91% and -0.967.
#
# Epoch 70:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 67.03% and 0.618.
# Discriminator class accuracy and loss on real data is 64.99% and -1.295.
# Discriminator source accuracy and loss on fake data is 67.66% and 0.604.
# Discriminator class accuracy and loss on fake data is 96.69% and -0.965.
# Generator source accuracy and loss is 25.46% and 1.264.
# Generator class accuracy and loss is 96.84% and -0.966.
#
# Epoch 71:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 66.46% and 0.620.
# Discriminator class accuracy and loss on real data is 65.21% and -1.301.
# Discriminator source accuracy and loss on fake data is 67.17% and 0.606.
# Discriminator class accuracy and loss on fake data is 96.87% and -0.967.
# Generator source accuracy and loss is 24.96% and 1.273.
# Generator class accuracy and loss is 97.17% and -0.969.
#
# Epoch 72:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 66.81% and 0.618.
# Discriminator class accuracy and loss on real data is 65.35% and -1.302.
# Discriminator source accuracy and loss on fake data is 67.83% and 0.601.
# Discriminator class accuracy and loss on fake data is 96.56% and -0.963.
# Generator source accuracy and loss is 23.33% and 1.314.
# Generator class accuracy and loss is 96.61% and -0.964.
#
# Epoch 73:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 66.70% and 0.617.
# Discriminator class accuracy and loss on real data is 65.08% and -1.298.
# Discriminator source accuracy and loss on fake data is 67.83% and 0.603.
# Discriminator class accuracy and loss on fake data is 96.48% and -0.962.
# Generator source accuracy and loss is 24.94% and 1.277.
# Generator class accuracy and loss is 96.70% and -0.965.
#
# Epoch 74:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 66.49% and 0.620.
# Discriminator class accuracy and loss on real data is 65.69% and -1.308.
# Discriminator source accuracy and loss on fake data is 67.68% and 0.604.
# Discriminator class accuracy and loss on fake data is 96.58% and -0.963.
# Generator source accuracy and loss is 24.26% and 1.293.
# Generator class accuracy and loss is 96.77% and -0.965.
#
# Epoch 75:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 67.69% and 0.606.
# Discriminator class accuracy and loss on real data is 65.57% and -1.307.
# Discriminator source accuracy and loss on fake data is 68.47% and 0.592.
# Discriminator class accuracy and loss on fake data is 96.54% and -0.963.
# Generator source accuracy and loss is 24.17% and 1.301.
# Generator class accuracy and loss is 96.69% and -0.965.
#
# Epoch 76:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 67.16% and 0.611.
# Discriminator class accuracy and loss on real data is 65.79% and -1.311.
# Discriminator source accuracy and loss on fake data is 68.02% and 0.599.
# Discriminator class accuracy and loss on fake data is 96.69% and -0.965.
# Generator source accuracy and loss is 23.93% and 1.299.
# Generator class accuracy and loss is 97.11% and -0.969.
#
# Epoch 77:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 67.09% and 0.615.
# Discriminator class accuracy and loss on real data is 65.58% and -1.307.
# Discriminator source accuracy and loss on fake data is 67.81% and 0.600.
# Discriminator class accuracy and loss on fake data is 96.74% and -0.965.
# Generator source accuracy and loss is 23.92% and 1.301.
# Generator class accuracy and loss is 96.87% and -0.966.
#
# Epoch 78:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 66.85% and 0.613.
# Discriminator class accuracy and loss on real data is 66.03% and -1.314.
# Discriminator source accuracy and loss on fake data is 67.94% and 0.597.
# Discriminator class accuracy and loss on fake data is 96.64% and -0.964.
# Generator source accuracy and loss is 24.30% and 1.295.
# Generator class accuracy and loss is 96.80% and -0.966.
#
# Epoch 79:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 67.69% and 0.607.
# Discriminator class accuracy and loss on real data is 65.80% and -1.310.
# Discriminator source accuracy and loss on fake data is 68.81% and 0.590.
# Discriminator class accuracy and loss on fake data is 96.57% and -0.963.
# Generator source accuracy and loss is 23.58% and 1.323.
# Generator class accuracy and loss is 96.82% and -0.966.
#
# Epoch 80:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 66.16% and 0.621.
# Discriminator class accuracy and loss on real data is 66.51% and -1.325.
# Discriminator source accuracy and loss on fake data is 67.10% and 0.608.
# Discriminator class accuracy and loss on fake data is 96.73% and -0.965.
# Generator source accuracy and loss is 25.52% and 1.262.
# Generator class accuracy and loss is 96.84% and -0.966.
#
# Epoch 81:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 66.33% and 0.624.
# Discriminator class accuracy and loss on real data is 66.28% and -1.321.
# Discriminator source accuracy and loss on fake data is 67.36% and 0.606.
# Discriminator class accuracy and loss on fake data is 96.50% and -0.963.
# Generator source accuracy and loss is 24.08% and 1.296.
# Generator class accuracy and loss is 96.64% and -0.964.
#
# Epoch 82:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 67.05% and 0.613.
# Discriminator class accuracy and loss on real data is 66.53% and -1.325.
# Discriminator source accuracy and loss on fake data is 67.93% and 0.599.
# Discriminator class accuracy and loss on fake data is 96.84% and -0.966.
# Generator source accuracy and loss is 25.69% and 1.248.
# Generator class accuracy and loss is 97.15% and -0.969.
#
# Epoch 83:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 66.95% and 0.612.
# Discriminator class accuracy and loss on real data is 66.05% and -1.318.
# Discriminator source accuracy and loss on fake data is 68.12% and 0.597.
# Discriminator class accuracy and loss on fake data is 96.61% and -0.964.
# Generator source accuracy and loss is 24.93% and 1.283.
# Generator class accuracy and loss is 96.83% and -0.966.
#
# Epoch 84:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 68.23% and 0.596.
# Discriminator class accuracy and loss on real data is 66.50% and -1.325.
# Discriminator source accuracy and loss on fake data is 69.54% and 0.582.
# Discriminator class accuracy and loss on fake data is 96.69% and -0.964.
# Generator source accuracy and loss is 22.86% and 1.331.
# Generator class accuracy and loss is 96.93% and -0.967.
#
# Epoch 85:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 68.51% and 0.594.
# Discriminator class accuracy and loss on real data is 66.42% and -1.322.
# Discriminator source accuracy and loss on fake data is 69.52% and 0.581.
# Discriminator class accuracy and loss on fake data is 96.29% and -0.961.
# Generator source accuracy and loss is 23.64% and 1.324.
# Generator class accuracy and loss is 96.55% and -0.963.
#
# Epoch 86:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 66.71% and 0.619.
# Discriminator class accuracy and loss on real data is 66.43% and -1.322.
# Discriminator source accuracy and loss on fake data is 67.79% and 0.604.
# Discriminator class accuracy and loss on fake data is 96.39% and -0.961.
# Generator source accuracy and loss is 24.84% and 1.294.
# Generator class accuracy and loss is 96.66% and -0.964.
#
# Epoch 87:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 67.28% and 0.609.
# Discriminator class accuracy and loss on real data is 66.82% and -1.332.
# Discriminator source accuracy and loss on fake data is 68.46% and 0.594.
# Discriminator class accuracy and loss on fake data is 96.57% and -0.963.
# Generator source accuracy and loss is 24.29% and 1.312.
# Generator class accuracy and loss is 96.72% and -0.965.
#
# Epoch 88:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 68.10% and 0.602.
# Discriminator class accuracy and loss on real data is 66.71% and -1.329.
# Discriminator source accuracy and loss on fake data is 69.22% and 0.587.
# Discriminator class accuracy and loss on fake data is 96.67% and -0.964.
# Generator source accuracy and loss is 23.59% and 1.314.
# Generator class accuracy and loss is 96.61% and -0.964.
#
# Epoch 89:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 67.51% and 0.613.
# Discriminator class accuracy and loss on real data is 66.78% and -1.329.
# Discriminator source accuracy and loss on fake data is 68.22% and 0.600.
# Discriminator class accuracy and loss on fake data is 97.09% and -0.968.
# Generator source accuracy and loss is 25.25% and 1.285.
# Generator class accuracy and loss is 97.32% and -0.971.
#
# Epoch 90:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 67.04% and 0.611.
# Discriminator class accuracy and loss on real data is 67.05% and -1.335.
# Discriminator source accuracy and loss on fake data is 68.48% and 0.595.
# Discriminator class accuracy and loss on fake data is 96.94% and -0.967.
# Generator source accuracy and loss is 25.02% and 1.276.
# Generator class accuracy and loss is 97.00% and -0.968.
#
# Epoch 91:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 67.32% and 0.615.
# Discriminator class accuracy and loss on real data is 67.15% and -1.338.
# Discriminator source accuracy and loss on fake data is 67.96% and 0.600.
# Discriminator class accuracy and loss on fake data is 96.82% and -0.965.
# Generator source accuracy and loss is 24.97% and 1.274.
# Generator class accuracy and loss is 96.78% and -0.966.
#
# Epoch 92:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 67.69% and 0.605.
# Discriminator class accuracy and loss on real data is 67.26% and -1.340.
# Discriminator source accuracy and loss on fake data is 69.02% and 0.590.
# Discriminator class accuracy and loss on fake data is 96.91% and -0.966.
# Generator source accuracy and loss is 24.19% and 1.286.
# Generator class accuracy and loss is 97.05% and -0.968.
#
# Epoch 93:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 67.89% and 0.603.
# Discriminator class accuracy and loss on real data is 66.84% and -1.333.
# Discriminator source accuracy and loss on fake data is 68.70% and 0.591.
# Discriminator class accuracy and loss on fake data is 96.97% and -0.967.
# Generator source accuracy and loss is 23.92% and 1.303.
# Generator class accuracy and loss is 97.11% and -0.968.
#
# Epoch 94:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 68.30% and 0.597.
# Discriminator class accuracy and loss on real data is 66.83% and -1.330.
# Discriminator source accuracy and loss on fake data is 69.51% and 0.582.
# Discriminator class accuracy and loss on fake data is 96.30% and -0.961.
# Generator source accuracy and loss is 23.88% and 1.316.
# Generator class accuracy and loss is 96.60% and -0.963.
#
# Epoch 95:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 67.93% and 0.598.
# Discriminator class accuracy and loss on real data is 67.17% and -1.337.
# Discriminator source accuracy and loss on fake data is 69.35% and 0.585.
# Discriminator class accuracy and loss on fake data is 96.02% and -0.958.
# Generator source accuracy and loss is 23.58% and 1.323.
# Generator class accuracy and loss is 96.22% and -0.960.
#
# Epoch 96:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 66.85% and 0.611.
# Discriminator class accuracy and loss on real data is 67.04% and -1.335.
# Discriminator source accuracy and loss on fake data is 68.50% and 0.594.
# Discriminator class accuracy and loss on fake data is 96.27% and -0.960.
# Generator source accuracy and loss is 24.41% and 1.296.
# Generator class accuracy and loss is 96.50% and -0.962.
#
# Epoch 97:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 67.94% and 0.601.
# Discriminator class accuracy and loss on real data is 67.32% and -1.341.
# Discriminator source accuracy and loss on fake data is 69.16% and 0.588.
# Discriminator class accuracy and loss on fake data is 96.45% and -0.962.
# Generator source accuracy and loss is 23.82% and 1.319.
# Generator class accuracy and loss is 96.80% and -0.966.
#
# Epoch 98:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 68.01% and 0.601.
# Discriminator class accuracy and loss on real data is 67.16% and -1.338.
# Discriminator source accuracy and loss on fake data is 69.17% and 0.585.
# Discriminator class accuracy and loss on fake data is 96.76% and -0.965.
# Generator source accuracy and loss is 24.12% and 1.325.
# Generator class accuracy and loss is 97.07% and -0.968.
#
# Epoch 99:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 68.18% and 0.602.
# Discriminator class accuracy and loss on real data is 67.38% and -1.343.
# Discriminator source accuracy and loss on fake data is 69.41% and 0.583.
# Discriminator class accuracy and loss on fake data is 97.04% and -0.968.
# Generator source accuracy and loss is 23.62% and 1.335.
# Generator class accuracy and loss is 97.15% and -0.969.

# %%
data = np.r_[np.array(d_real_source_accuracies_avg),
      np.array(d_real_class_accuracies_avg),
      np.array(d_real_source_losses_avg),
      np.array(d_real_class_losses_avg),
      np.array(d_fake_source_accuracies_avg),
      np.array(d_fake_class_accuracies_avg),
      np.array(d_fake_source_losses_avg),
      np.array(d_fake_class_losses_avg),
      np.array(g_source_accuracies_avg),
      np.array(g_class_accuracies_avg),
      np.array(g_source_losses_avg),
      np.array(g_class_losses_avg)]

# %%
pd.DataFrame(data).to_csv("data_large.csv")
