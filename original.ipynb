# %%
import torch
import torchvision.transforms as transforms
import torchvision
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
transform_train = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
])

# %%
trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform_train)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=100, shuffle=True, num_workers=2)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ./data/cifar-10-python.tar.gz to ./data

# %%
class Generator(nn.Module):
    def __init__(self):
        super(Generator, self).__init__()
        self.fc1 = nn.Sequential(
            nn.Linear(110,384),
            nn.ReLU())
        self.tconv1 = nn.Sequential(
            nn.ConvTranspose2d(384, 192, 6, 2),
            nn.BatchNorm2d(192),
            nn.ReLU())
        self.tconv2 = nn.Sequential(
            nn.ConvTranspose2d(192, 96, 5, 2),
            nn.BatchNorm2d(96),
            nn.ReLU())
        self.tconv3 = nn.Sequential(
            nn.ConvTranspose2d(96, 3, 4, 2),
            nn.Tanh())
        self._initialize_weights()
    
    def forward(self, x):
        out = self.fc1(x)
        out = self.tconv1(out[:,:,None,None])
        out = self.tconv2(out)
        out = self.tconv3(out)
        return out
    
    def _initialize_weights(self):
        for m in self.modules():
            if isinstance(m, nn.ConvTranspose2d) or isinstance(m, nn.Linear):
                m.weight.data.normal_(0, 0.01)
                m.bias.data.zero_()
            elif isinstance(m, nn.BatchNorm2d):
                m.weight.data.fill_(1)
                m.bias.data.zero_()

# %%
class Discriminator(nn.Module):
    
    def __init__(self):
        super(Discriminator, self).__init__()
        self.conv1 = nn.Sequential(
            nn.Conv2d(3, 16, 3, 2, 1),
            nn.LeakyReLU(0.2))
        self.conv2 = nn.Sequential(
            nn.Conv2d(16, 32, 3, 1, 1),
            nn.BatchNorm2d(32),
            nn.LeakyReLU(0.2))
        self.conv3 = nn.Sequential(
            nn.Conv2d(32, 64, 3, 2, 1),
            nn.BatchNorm2d(64),
            nn.LeakyReLU(0.2))
        self.conv4 = nn.Sequential(
            nn.Conv2d(64, 128, 3, 1, 1),
            nn.BatchNorm2d(128),
            nn.LeakyReLU(0.2))
        self.conv5 = nn.Sequential(
            nn.Conv2d(128, 256, 3, 2, 1),
            nn.BatchNorm2d(256),
            nn.LeakyReLU(0.2))
        self.conv6 = nn.Sequential(
            nn.Conv2d(256, 512, 3, 1, 1),
            nn.BatchNorm2d(512),
            nn.LeakyReLU(0.2))
        self.dropout = nn.Dropout(0.5)
        self.activation_noise_sd = 0.1
        self.fc = nn.Linear(4*4*512, 11)
        self.sigmoid = nn.Sigmoid()
        self.softmax = nn.Softmax(1)
        self._initialize_weights()

    def forward(self,x):
        out = self.conv1(x)
        out = self.dropout(out + self.activation_noise_sd*torch.rand(out.shape).to(device))
        out = self.conv2(out)
        out = self.dropout(out + self.activation_noise_sd*torch.rand(out.shape).to(device))
        out = self.conv3(out)
        out = self.dropout(out + self.activation_noise_sd*torch.rand(out.shape).to(device))
        out = self.conv4(out)
        out = self.dropout(out + self.activation_noise_sd*torch.rand(out.shape).to(device))
        out = self.conv5(out)
        out = self.dropout(out + self.activation_noise_sd*torch.rand(out.shape).to(device))
        out = self.conv6(out)
        out = self.dropout(out + self.activation_noise_sd*torch.rand(out.shape).to(device))
        out = self.fc(out.reshape(-1,4*4*512))
        return self.sigmoid(out[:,0]), self.softmax(out[:,1:])
    
    def _initialize_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Conv2d) or isinstance(m, nn.Linear):
                m.weight.data.normal_(0, 0.01)
                m.bias.data.zero_()
            elif isinstance(m, nn.BatchNorm2d):
                m.weight.data.fill_(1)
                m.bias.data.zero_()

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
generator = Generator()
generator = generator.to(device)
discriminator = Discriminator()
discriminator = discriminator.to(device)

# %%
optimizer_d = optim.Adam(discriminator.parameters(), lr = 0.0002, betas = (0.5, 0.999))
optimizer_g = optim.Adam(generator.parameters(), lr = 0.0002, betas = (0.5, 0.999))
criterion_source = nn.BCELoss()
criterion_class = nn.NLLLoss()
print("We shall train for {} epochs".format(50000/len(trainloader)))
# Out:
# We shall train for 100.0 epochs

# %%
d_real_source_accuracies_avg = []
d_real_class_accuracies_avg = []
d_real_source_losses_avg = []
d_real_class_losses_avg = []
d_fake_source_accuracies_avg = []
d_fake_class_accuracies_avg = []
d_fake_source_losses_avg = []
d_fake_class_losses_avg = []
g_source_accuracies_avg = []
g_class_accuracies_avg = []
g_source_losses_avg = []
g_class_losses_avg = []

for epoch in range(100):
    print("Epoch {}:".format(epoch))
    
    d_real_source_accuracies = []
    d_real_class_accuracies = []
    d_real_source_losses = []
    d_real_class_losses = []
    d_fake_source_accuracies = []
    d_fake_class_accuracies = []
    d_fake_source_losses = []
    d_fake_class_losses = []
    g_source_accuracies = []
    g_class_accuracies = []
    g_source_losses = []
    g_class_losses = []
    
    for batch_idx, (inputs, targets) in enumerate(trainloader):
        if batch_idx % 100 == 0:
            print("Batch Index: {}".format(batch_idx))
        # Train discriminator with real data
        inputs, targets = inputs.to(device), targets.to(device)
        optimizer_d.zero_grad()
        sources, classes = discriminator(inputs)
        source_targets = torch.ones(sources.shape).to(device)
        source_loss = criterion_source(sources, source_targets)
        class_loss = 2*criterion_class(classes, targets)
        d_real_loss = (source_loss + class_loss)/2
        d_real_loss.backward()
        d_real_source_accuracy = torch.mean((torch.where(sources > 0.5, torch.tensor(1.).to(device), torch.tensor(0.).to(device)) == source_targets).float()).item()*100
        d_real_class_accuracy = torch.mean((classes.max(1)[1] == targets).float()).item()*100
        d_real_source_accuracies.append(d_real_source_accuracy)
        d_real_class_accuracies.append(d_real_class_accuracy)
        d_real_source_losses.append(source_loss.item())
        d_real_class_losses.append(class_loss.item())
        
        # Train discriminator with fake data
        fake_targets = np.random.randint(0, 10, inputs.shape[0])
        gen_input_np = np.c_[np.random.randn(inputs.shape[0], 100), np.eye(10)[fake_targets]]
        fake_targets = torch.from_numpy(fake_targets).long().to(device)
        gen_input = torch.from_numpy(gen_input_np).float().to(device)
        fake_inputs = generator(gen_input)
        sources, classes = discriminator(fake_inputs.detach())
        source_targets = torch.zeros(sources.shape).to(device)
        source_loss = criterion_source(sources, source_targets) 
        class_loss = criterion_class(classes, fake_targets)
        d_fake_loss = (source_loss + class_loss)/2
        d_fake_loss.backward()
        optimizer_d.step()
        d_fake_source_accuracy = np.round(torch.mean((torch.where(sources > 0.5, torch.tensor(1.).to(device), torch.tensor(0.).to(device)) == source_targets).float()).item()*100)
        d_fake_class_accuracy = np.round(torch.mean((classes.max(1)[1] == fake_targets).float()).item()*100)
        d_fake_source_accuracies.append(d_fake_source_accuracy)
        d_fake_class_accuracies.append(d_fake_class_accuracy)
        d_fake_source_losses.append(source_loss.item())
        d_fake_class_losses.append(class_loss.item())
        
        # Train generator
        optimizer_g.zero_grad()
        sources, classes = discriminator(fake_inputs)
        source_targets = torch.ones(sources.shape).to(device)
        source_loss = criterion_source(sources, source_targets) 
        class_loss = criterion_class(classes, fake_targets)
        g_loss = source_loss + class_loss
        g_loss.backward()
        optimizer_g.step()
        g_source_accuracy = np.round(torch.mean((torch.where(sources > 0.5, torch.tensor(1.).to(device), torch.tensor(0.).to(device)) == source_targets).float()).item()*100)
        g_class_accuracy = np.round(torch.mean((classes.max(1)[1] == fake_targets).float()).item()*100)
        g_source_accuracies.append(g_source_accuracy)
        g_class_accuracies.append(g_class_accuracy)
        g_source_losses.append(source_loss.item())
        g_class_losses.append(class_loss.item())

    torch.save(generator.state_dict(), "generator100_original.pt")
    torch.save(discriminator.state_dict(), "discriminator100_original.pt")

    print("Discriminator source accuracy and loss on real data is {:.2f}% and {:.3f}.".format(np.mean(d_real_source_accuracies), np.mean(d_real_source_losses)))
    print("Discriminator class accuracy and loss on real data is {:.2f}% and {:.3f}.".format(np.mean(d_real_class_accuracies), np.mean(d_real_class_losses)))
    print("Discriminator source accuracy and loss on fake data is {:.2f}% and {:.3f}.".format(np.mean(d_fake_source_accuracies), np.mean(d_fake_source_losses)))
    print("Discriminator class accuracy and loss on fake data is {:.2f}% and {:.3f}.".format(np.mean(d_fake_class_accuracies), np.mean(d_fake_class_losses)))
    print("Generator source accuracy and loss is {:.2f}% and {:.3f}.".format(np.mean(g_source_accuracies), np.mean(g_source_losses)))
    print("Generator class accuracy and loss is {:.2f}% and {:.3f}.\n".format(np.mean(g_class_accuracies), np.mean(g_class_losses)))
    
    d_real_source_accuracies_avg.append(np.mean(d_real_source_accuracies))
    d_real_class_accuracies_avg.append(np.mean(d_real_class_accuracies))
    d_real_source_losses_avg.append(np.mean(d_real_source_losses))
    d_real_class_losses_avg.append(np.mean(d_real_class_losses))
    d_fake_source_accuracies_avg.append(np.mean(d_fake_source_accuracies))
    d_fake_class_accuracies_avg.append(np.mean(d_fake_class_accuracies))
    d_fake_source_losses_avg.append(np.mean(d_fake_source_losses))
    d_fake_class_losses_avg.append(np.mean(d_fake_class_losses))
    g_source_accuracies_avg.append(np.mean(g_source_accuracies))
    g_class_accuracies_avg.append(np.mean(g_class_accuracies))
    g_source_losses_avg.append(np.mean(g_source_losses))
    g_class_losses_avg.append(np.mean(g_class_losses))
# Out:
# Epoch 0:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 67.22% and 0.630.
# Discriminator class accuracy and loss on real data is 15.18% and -0.298.
# Discriminator source accuracy and loss on fake data is 70.30% and 0.567.
# Discriminator class accuracy and loss on fake data is 10.17% and -0.101.
# Generator source accuracy and loss is 17.50% and 1.805.
# Generator class accuracy and loss is 10.20% and -0.101.
#
# Epoch 1:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 77.94% and 0.479.
# Discriminator class accuracy and loss on real data is 21.83% and -0.427.
# Discriminator source accuracy and loss on fake data is 81.48% and 0.421.
# Discriminator class accuracy and loss on fake data is 12.34% and -0.123.
# Generator source accuracy and loss is 5.97% and 2.383.
# Generator class accuracy and loss is 12.81% and -0.127.
#
# Epoch 2:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 75.26% and 0.518.
# Discriminator class accuracy and loss on real data is 26.15% and -0.517.
# Discriminator source accuracy and loss on fake data is 78.59% and 0.464.
# Discriminator class accuracy and loss on fake data is 14.52% and -0.144.
# Generator source accuracy and loss is 9.16% and 2.106.
# Generator class accuracy and loss is 14.65% and -0.145.
#
# Epoch 3:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 77.11% and 0.483.
# Discriminator class accuracy and loss on real data is 28.06% and -0.555.
# Discriminator source accuracy and loss on fake data is 80.14% and 0.438.
# Discriminator class accuracy and loss on fake data is 18.96% and -0.189.
# Generator source accuracy and loss is 9.14% and 2.210.
# Generator class accuracy and loss is 19.36% and -0.191.
#
# Epoch 4:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 73.79% and 0.529.
# Discriminator class accuracy and loss on real data is 27.01% and -0.537.
# Discriminator source accuracy and loss on fake data is 76.11% and 0.495.
# Discriminator class accuracy and loss on fake data is 25.40% and -0.252.
# Generator source accuracy and loss is 11.55% and 1.950.
# Generator class accuracy and loss is 25.81% and -0.256.
#
# Epoch 5:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 73.43% and 0.533.
# Discriminator class accuracy and loss on real data is 29.11% and -0.579.
# Discriminator source accuracy and loss on fake data is 75.22% and 0.506.
# Discriminator class accuracy and loss on fake data is 35.71% and -0.355.
# Generator source accuracy and loss is 12.86% and 1.864.
# Generator class accuracy and loss is 36.11% and -0.358.
#
# Epoch 6:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 75.46% and 0.505.
# Discriminator class accuracy and loss on real data is 29.15% and -0.577.
# Discriminator source accuracy and loss on fake data is 77.25% and 0.479.
# Discriminator class accuracy and loss on fake data is 45.04% and -0.446.
# Generator source accuracy and loss is 10.44% and 1.983.
# Generator class accuracy and loss is 45.46% and -0.451.
#
# Epoch 7:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 76.45% and 0.494.
# Discriminator class accuracy and loss on real data is 32.00% and -0.633.
# Discriminator source accuracy and loss on fake data is 77.77% and 0.475.
# Discriminator class accuracy and loss on fake data is 52.25% and -0.518.
# Generator source accuracy and loss is 9.96% and 2.080.
# Generator class accuracy and loss is 52.84% and -0.523.
#
# Epoch 8:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 75.04% and 0.514.
# Discriminator class accuracy and loss on real data is 33.94% and -0.673.
# Discriminator source accuracy and loss on fake data is 76.32% and 0.493.
# Discriminator class accuracy and loss on fake data is 58.13% and -0.576.
# Generator source accuracy and loss is 12.09% and 2.003.
# Generator class accuracy and loss is 58.27% and -0.578.
#
# Epoch 9:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 74.31% and 0.521.
# Discriminator class accuracy and loss on real data is 34.87% and -0.690.
# Discriminator source accuracy and loss on fake data is 75.14% and 0.506.
# Discriminator class accuracy and loss on fake data is 65.35% and -0.648.
# Generator source accuracy and loss is 14.87% and 1.783.
# Generator class accuracy and loss is 65.94% and -0.653.
#
# Epoch 10:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 71.81% and 0.558.
# Discriminator class accuracy and loss on real data is 35.79% and -0.710.
# Discriminator source accuracy and loss on fake data is 72.44% and 0.544.
# Discriminator class accuracy and loss on fake data is 73.02% and -0.725.
# Generator source accuracy and loss is 17.63% and 1.627.
# Generator class accuracy and loss is 73.42% and -0.727.
#
# Epoch 11:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 70.66% and 0.569.
# Discriminator class accuracy and loss on real data is 36.90% and -0.732.
# Discriminator source accuracy and loss on fake data is 71.71% and 0.557.
# Discriminator class accuracy and loss on fake data is 80.31% and -0.797.
# Generator source accuracy and loss is 18.86% and 1.501.
# Generator class accuracy and loss is 80.74% and -0.800.
#
# Epoch 12:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 70.55% and 0.570.
# Discriminator class accuracy and loss on real data is 37.54% and -0.744.
# Discriminator source accuracy and loss on fake data is 71.10% and 0.562.
# Discriminator class accuracy and loss on fake data is 83.07% and -0.825.
# Generator source accuracy and loss is 19.86% and 1.449.
# Generator class accuracy and loss is 83.45% and -0.829.
#
# Epoch 13:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 69.44% and 0.585.
# Discriminator class accuracy and loss on real data is 37.93% and -0.754.
# Discriminator source accuracy and loss on fake data is 69.79% and 0.578.
# Discriminator class accuracy and loss on fake data is 84.20% and -0.836.
# Generator source accuracy and loss is 21.45% and 1.362.
# Generator class accuracy and loss is 84.31% and -0.838.
#
# Epoch 14:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 68.89% and 0.587.
# Discriminator class accuracy and loss on real data is 39.65% and -0.786.
# Discriminator source accuracy and loss on fake data is 69.59% and 0.580.
# Discriminator class accuracy and loss on fake data is 87.89% and -0.872.
# Generator source accuracy and loss is 22.70% and 1.309.
# Generator class accuracy and loss is 88.00% and -0.874.
#
# Epoch 15:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 67.87% and 0.600.
# Discriminator class accuracy and loss on real data is 41.99% and -0.832.
# Discriminator source accuracy and loss on fake data is 68.32% and 0.592.
# Discriminator class accuracy and loss on fake data is 92.97% and -0.922.
# Generator source accuracy and loss is 23.93% and 1.270.
# Generator class accuracy and loss is 93.15% and -0.925.
#
# Epoch 16:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 67.98% and 0.598.
# Discriminator class accuracy and loss on real data is 42.77% and -0.849.
# Discriminator source accuracy and loss on fake data is 67.99% and 0.596.
# Discriminator class accuracy and loss on fake data is 94.49% and -0.939.
# Generator source accuracy and loss is 25.30% and 1.209.
# Generator class accuracy and loss is 94.72% and -0.941.
#
# Epoch 17:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 66.90% and 0.610.
# Discriminator class accuracy and loss on real data is 43.84% and -0.869.
# Discriminator source accuracy and loss on fake data is 67.49% and 0.604.
# Discriminator class accuracy and loss on fake data is 94.96% and -0.944.
# Generator source accuracy and loss is 25.41% and 1.192.
# Generator class accuracy and loss is 95.21% and -0.946.
#
# Epoch 18:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 66.68% and 0.613.
# Discriminator class accuracy and loss on real data is 44.81% and -0.888.
# Discriminator source accuracy and loss on fake data is 66.95% and 0.610.
# Discriminator class accuracy and loss on fake data is 95.21% and -0.947.
# Generator source accuracy and loss is 26.06% and 1.173.
# Generator class accuracy and loss is 95.55% and -0.950.
#
# Epoch 19:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 67.59% and 0.601.
# Discriminator class accuracy and loss on real data is 45.41% and -0.903.
# Discriminator source accuracy and loss on fake data is 68.02% and 0.599.
# Discriminator class accuracy and loss on fake data is 94.93% and -0.944.
# Generator source accuracy and loss is 25.21% and 1.196.
# Generator class accuracy and loss is 95.09% and -0.945.
#
# Epoch 20:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 66.52% and 0.616.
# Discriminator class accuracy and loss on real data is 45.63% and -0.906.
# Discriminator source accuracy and loss on fake data is 66.70% and 0.612.
# Discriminator class accuracy and loss on fake data is 95.45% and -0.949.
# Generator source accuracy and loss is 26.88% and 1.163.
# Generator class accuracy and loss is 95.67% and -0.952.
#
# Epoch 21:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 66.28% and 0.615.
# Discriminator class accuracy and loss on real data is 46.37% and -0.921.
# Discriminator source accuracy and loss on fake data is 66.22% and 0.612.
# Discriminator class accuracy and loss on fake data is 95.85% and -0.954.
# Generator source accuracy and loss is 26.37% and 1.161.
# Generator class accuracy and loss is 95.79% and -0.953.
#
# Epoch 22:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 66.36% and 0.616.
# Discriminator class accuracy and loss on real data is 46.57% and -0.926.
# Discriminator source accuracy and loss on fake data is 66.35% and 0.612.
# Discriminator class accuracy and loss on fake data is 96.10% and -0.957.
# Generator source accuracy and loss is 27.63% and 1.131.
# Generator class accuracy and loss is 96.21% and -0.958.
#
# Epoch 23:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 66.39% and 0.616.
# Discriminator class accuracy and loss on real data is 46.81% and -0.931.
# Discriminator source accuracy and loss on fake data is 66.45% and 0.612.
# Discriminator class accuracy and loss on fake data is 95.82% and -0.954.
# Generator source accuracy and loss is 27.81% and 1.126.
# Generator class accuracy and loss is 96.02% and -0.956.
#
# Epoch 24:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 64.87% and 0.632.
# Discriminator class accuracy and loss on real data is 47.23% and -0.938.
# Discriminator source accuracy and loss on fake data is 64.83% and 0.628.
# Discriminator class accuracy and loss on fake data is 95.46% and -0.950.
# Generator source accuracy and loss is 29.79% and 1.075.
# Generator class accuracy and loss is 95.72% and -0.953.
#
# Epoch 25:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 66.02% and 0.618.
# Discriminator class accuracy and loss on real data is 47.98% and -0.954.
# Discriminator source accuracy and loss on fake data is 65.98% and 0.615.
# Discriminator class accuracy and loss on fake data is 95.85% and -0.955.
# Generator source accuracy and loss is 28.68% and 1.090.
# Generator class accuracy and loss is 96.23% and -0.958.
#
# Epoch 26:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 65.99% and 0.617.
# Discriminator class accuracy and loss on real data is 48.31% and -0.960.
# Discriminator source accuracy and loss on fake data is 66.29% and 0.613.
# Discriminator class accuracy and loss on fake data is 96.30% and -0.959.
# Generator source accuracy and loss is 29.13% and 1.081.
# Generator class accuracy and loss is 96.34% and -0.959.
#
# Epoch 27:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 65.65% and 0.622.
# Discriminator class accuracy and loss on real data is 48.40% and -0.962.
# Discriminator source accuracy and loss on fake data is 65.80% and 0.621.
# Discriminator class accuracy and loss on fake data is 95.97% and -0.956.
# Generator source accuracy and loss is 27.93% and 1.099.
# Generator class accuracy and loss is 96.21% and -0.958.
#
# Epoch 28:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 65.97% and 0.619.
# Discriminator class accuracy and loss on real data is 48.91% and -0.973.
# Discriminator source accuracy and loss on fake data is 66.01% and 0.616.
# Discriminator class accuracy and loss on fake data is 96.13% and -0.957.
# Generator source accuracy and loss is 28.98% and 1.084.
# Generator class accuracy and loss is 96.03% and -0.957.
#
# Epoch 29:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 65.40% and 0.626.
# Discriminator class accuracy and loss on real data is 49.55% and -0.985.
# Discriminator source accuracy and loss on fake data is 65.16% and 0.623.
# Discriminator class accuracy and loss on fake data is 96.23% and -0.959.
# Generator source accuracy and loss is 30.29% and 1.054.
# Generator class accuracy and loss is 96.45% and -0.960.
#
# Epoch 30:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 65.60% and 0.623.
# Discriminator class accuracy and loss on real data is 49.13% and -0.978.
# Discriminator source accuracy and loss on fake data is 65.60% and 0.622.
# Discriminator class accuracy and loss on fake data is 96.00% and -0.956.
# Generator source accuracy and loss is 28.77% and 1.078.
# Generator class accuracy and loss is 96.17% and -0.958.
#
# Epoch 31:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 65.88% and 0.622.
# Discriminator class accuracy and loss on real data is 49.52% and -0.985.
# Discriminator source accuracy and loss on fake data is 65.37% and 0.620.
# Discriminator class accuracy and loss on fake data is 95.81% and -0.954.
# Generator source accuracy and loss is 29.62% and 1.064.
# Generator class accuracy and loss is 96.09% and -0.957.
#
# Epoch 32:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 65.26% and 0.624.
# Discriminator class accuracy and loss on real data is 49.95% and -0.995.
# Discriminator source accuracy and loss on fake data is 65.03% and 0.622.
# Discriminator class accuracy and loss on fake data is 96.11% and -0.958.
# Generator source accuracy and loss is 29.83% and 1.064.
# Generator class accuracy and loss is 96.11% and -0.957.
#
# Epoch 33:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 65.13% and 0.628.
# Discriminator class accuracy and loss on real data is 50.11% and -0.997.
# Discriminator source accuracy and loss on fake data is 65.11% and 0.626.
# Discriminator class accuracy and loss on fake data is 96.09% and -0.957.
# Generator source accuracy and loss is 30.23% and 1.059.
# Generator class accuracy and loss is 96.20% and -0.958.
#
# Epoch 34:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 66.14% and 0.621.
# Discriminator class accuracy and loss on real data is 50.32% and -1.001.
# Discriminator source accuracy and loss on fake data is 65.75% and 0.619.
# Discriminator class accuracy and loss on fake data is 96.03% and -0.957.
# Generator source accuracy and loss is 29.39% and 1.065.
# Generator class accuracy and loss is 96.22% and -0.958.
#
# Epoch 35:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 66.07% and 0.618.
# Discriminator class accuracy and loss on real data is 50.49% and -1.006.
# Discriminator source accuracy and loss on fake data is 65.79% and 0.616.
# Discriminator class accuracy and loss on fake data is 95.88% and -0.955.
# Generator source accuracy and loss is 29.83% and 1.059.
# Generator class accuracy and loss is 95.79% and -0.955.
#
# Epoch 36:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 65.85% and 0.619.
# Discriminator class accuracy and loss on real data is 51.13% and -1.018.
# Discriminator source accuracy and loss on fake data is 65.49% and 0.619.
# Discriminator class accuracy and loss on fake data is 95.63% and -0.952.
# Generator source accuracy and loss is 30.23% and 1.056.
# Generator class accuracy and loss is 96.03% and -0.956.
#
# Epoch 37:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 65.82% and 0.622.
# Discriminator class accuracy and loss on real data is 51.21% and -1.020.
# Discriminator source accuracy and loss on fake data is 65.44% and 0.620.
# Discriminator class accuracy and loss on fake data is 95.61% and -0.953.
# Generator source accuracy and loss is 29.58% and 1.071.
# Generator class accuracy and loss is 95.92% and -0.955.
#
# Epoch 38:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 65.89% and 0.622.
# Discriminator class accuracy and loss on real data is 51.61% and -1.026.
# Discriminator source accuracy and loss on fake data is 65.36% and 0.621.
# Discriminator class accuracy and loss on fake data is 95.95% and -0.956.
# Generator source accuracy and loss is 30.21% and 1.053.
# Generator class accuracy and loss is 96.10% and -0.957.
#
# Epoch 39:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 66.10% and 0.618.
# Discriminator class accuracy and loss on real data is 51.69% and -1.029.
# Discriminator source accuracy and loss on fake data is 65.94% and 0.616.
# Discriminator class accuracy and loss on fake data is 96.08% and -0.957.
# Generator source accuracy and loss is 30.40% and 1.053.
# Generator class accuracy and loss is 96.12% and -0.958.
#
# Epoch 40:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 66.26% and 0.618.
# Discriminator class accuracy and loss on real data is 51.54% and -1.026.
# Discriminator source accuracy and loss on fake data is 65.64% and 0.619.
# Discriminator class accuracy and loss on fake data is 95.88% and -0.955.
# Generator source accuracy and loss is 30.16% and 1.063.
# Generator class accuracy and loss is 95.95% and -0.956.
#
# Epoch 41:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 65.83% and 0.621.
# Discriminator class accuracy and loss on real data is 52.11% and -1.037.
# Discriminator source accuracy and loss on fake data is 65.35% and 0.622.
# Discriminator class accuracy and loss on fake data is 96.00% and -0.957.
# Generator source accuracy and loss is 31.10% and 1.049.
# Generator class accuracy and loss is 96.08% and -0.957.
#
# Epoch 42:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 66.04% and 0.619.
# Discriminator class accuracy and loss on real data is 51.92% and -1.034.
# Discriminator source accuracy and loss on fake data is 65.70% and 0.619.
# Discriminator class accuracy and loss on fake data is 95.56% and -0.952.
# Generator source accuracy and loss is 30.26% and 1.056.
# Generator class accuracy and loss is 95.94% and -0.955.
#
# Epoch 43:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 65.92% and 0.619.
# Discriminator class accuracy and loss on real data is 52.35% and -1.042.
# Discriminator source accuracy and loss on fake data is 65.50% and 0.618.
# Discriminator class accuracy and loss on fake data is 96.05% and -0.957.
# Generator source accuracy and loss is 30.87% and 1.047.
# Generator class accuracy and loss is 96.18% and -0.958.
#
# Epoch 44:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 65.80% and 0.622.
# Discriminator class accuracy and loss on real data is 52.24% and -1.041.
# Discriminator source accuracy and loss on fake data is 65.16% and 0.622.
# Discriminator class accuracy and loss on fake data is 95.82% and -0.955.
# Generator source accuracy and loss is 31.33% and 1.042.
# Generator class accuracy and loss is 95.95% and -0.956.
#
# Epoch 45:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 65.89% and 0.619.
# Discriminator class accuracy and loss on real data is 52.40% and -1.043.
# Discriminator source accuracy and loss on fake data is 65.54% and 0.620.
# Discriminator class accuracy and loss on fake data is 95.50% and -0.951.
# Generator source accuracy and loss is 30.97% and 1.045.
# Generator class accuracy and loss is 95.65% and -0.953.
#
# Epoch 46:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 65.55% and 0.623.
# Discriminator class accuracy and loss on real data is 52.75% and -1.050.
# Discriminator source accuracy and loss on fake data is 65.49% and 0.621.
# Discriminator class accuracy and loss on fake data is 95.88% and -0.956.
# Generator source accuracy and loss is 31.84% and 1.031.
# Generator class accuracy and loss is 95.99% and -0.957.
#
# Epoch 47:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 65.72% and 0.622.
# Discriminator class accuracy and loss on real data is 53.11% and -1.057.
# Discriminator source accuracy and loss on fake data is 65.28% and 0.622.
# Discriminator class accuracy and loss on fake data is 96.07% and -0.958.
# Generator source accuracy and loss is 30.43% and 1.050.
# Generator class accuracy and loss is 96.31% and -0.960.
#
# Epoch 48:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 66.12% and 0.619.
# Discriminator class accuracy and loss on real data is 53.28% and -1.061.
# Discriminator source accuracy and loss on fake data is 65.83% and 0.618.
# Discriminator class accuracy and loss on fake data is 95.93% and -0.956.
# Generator source accuracy and loss is 30.78% and 1.053.
# Generator class accuracy and loss is 95.95% and -0.957.
#
# Epoch 49:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 65.72% and 0.620.
# Discriminator class accuracy and loss on real data is 53.21% and -1.059.
# Discriminator source accuracy and loss on fake data is 65.36% and 0.621.
# Discriminator class accuracy and loss on fake data is 95.99% and -0.957.
# Generator source accuracy and loss is 30.91% and 1.046.
# Generator class accuracy and loss is 96.00% and -0.957.
#
# Epoch 50:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 65.33% and 0.623.
# Discriminator class accuracy and loss on real data is 53.43% and -1.064.
# Discriminator source accuracy and loss on fake data is 64.97% and 0.624.
# Discriminator class accuracy and loss on fake data is 96.16% and -0.958.
# Generator source accuracy and loss is 31.52% and 1.034.
# Generator class accuracy and loss is 96.08% and -0.958.
#
# Epoch 51:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 66.13% and 0.619.
# Discriminator class accuracy and loss on real data is 53.63% and -1.067.
# Discriminator source accuracy and loss on fake data is 65.85% and 0.617.
# Discriminator class accuracy and loss on fake data is 95.93% and -0.956.
# Generator source accuracy and loss is 30.61% and 1.052.
# Generator class accuracy and loss is 95.90% and -0.956.
#
# Epoch 52:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 65.85% and 0.621.
# Discriminator class accuracy and loss on real data is 53.73% and -1.068.
# Discriminator source accuracy and loss on fake data is 65.02% and 0.623.
# Discriminator class accuracy and loss on fake data is 96.08% and -0.957.
# Generator source accuracy and loss is 31.23% and 1.035.
# Generator class accuracy and loss is 95.98% and -0.957.
#
# Epoch 53:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 65.52% and 0.623.
# Discriminator class accuracy and loss on real data is 54.06% and -1.077.
# Discriminator source accuracy and loss on fake data is 65.08% and 0.624.
# Discriminator class accuracy and loss on fake data is 95.66% and -0.953.
# Generator source accuracy and loss is 30.53% and 1.052.
# Generator class accuracy and loss is 95.66% and -0.954.
#
# Epoch 54:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 65.79% and 0.621.
# Discriminator class accuracy and loss on real data is 54.41% and -1.083.
# Discriminator source accuracy and loss on fake data is 65.21% and 0.622.
# Discriminator class accuracy and loss on fake data is 95.66% and -0.953.
# Generator source accuracy and loss is 32.12% and 1.021.
# Generator class accuracy and loss is 95.66% and -0.954.
#
# Epoch 55:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 66.09% and 0.620.
# Discriminator class accuracy and loss on real data is 54.41% and -1.083.
# Discriminator source accuracy and loss on fake data is 65.37% and 0.622.
# Discriminator class accuracy and loss on fake data is 95.94% and -0.956.
# Generator source accuracy and loss is 31.88% and 1.026.
# Generator class accuracy and loss is 95.88% and -0.955.
#
# Epoch 56:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 66.22% and 0.618.
# Discriminator class accuracy and loss on real data is 54.54% and -1.085.
# Discriminator source accuracy and loss on fake data is 65.65% and 0.620.
# Discriminator class accuracy and loss on fake data is 95.75% and -0.954.
# Generator source accuracy and loss is 30.55% and 1.050.
# Generator class accuracy and loss is 95.66% and -0.953.
#
# Epoch 57:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 66.18% and 0.619.
# Discriminator class accuracy and loss on real data is 54.94% and -1.094.
# Discriminator source accuracy and loss on fake data is 65.62% and 0.619.
# Discriminator class accuracy and loss on fake data is 95.72% and -0.954.
# Generator source accuracy and loss is 31.66% and 1.032.
# Generator class accuracy and loss is 95.73% and -0.954.
#
# Epoch 58:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 66.19% and 0.619.
# Discriminator class accuracy and loss on real data is 54.83% and -1.092.
# Discriminator source accuracy and loss on fake data is 65.48% and 0.620.
# Discriminator class accuracy and loss on fake data is 95.63% and -0.953.
# Generator source accuracy and loss is 31.06% and 1.042.
# Generator class accuracy and loss is 95.69% and -0.954.
#
# Epoch 59:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 65.68% and 0.621.
# Discriminator class accuracy and loss on real data is 54.95% and -1.094.
# Discriminator source accuracy and loss on fake data is 65.11% and 0.623.
# Discriminator class accuracy and loss on fake data is 95.43% and -0.951.
# Generator source accuracy and loss is 31.67% and 1.038.
# Generator class accuracy and loss is 95.52% and -0.952.
#
# Epoch 60:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 65.62% and 0.620.
# Discriminator class accuracy and loss on real data is 55.17% and -1.097.
# Discriminator source accuracy and loss on fake data is 64.84% and 0.623.
# Discriminator class accuracy and loss on fake data is 96.17% and -0.959.
# Generator source accuracy and loss is 32.25% and 1.022.
# Generator class accuracy and loss is 95.98% and -0.957.
#
# Epoch 61:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 66.32% and 0.619.
# Discriminator class accuracy and loss on real data is 55.16% and -1.097.
# Discriminator source accuracy and loss on fake data is 65.14% and 0.620.
# Discriminator class accuracy and loss on fake data is 95.73% and -0.954.
# Generator source accuracy and loss is 31.19% and 1.042.
# Generator class accuracy and loss is 95.79% and -0.955.
#
# Epoch 62:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 66.51% and 0.616.
# Discriminator class accuracy and loss on real data is 55.48% and -1.103.
# Discriminator source accuracy and loss on fake data is 65.87% and 0.616.
# Discriminator class accuracy and loss on fake data is 95.52% and -0.952.
# Generator source accuracy and loss is 31.40% and 1.045.
# Generator class accuracy and loss is 95.59% and -0.954.
#
# Epoch 63:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 66.27% and 0.618.
# Discriminator class accuracy and loss on real data is 55.46% and -1.103.
# Discriminator source accuracy and loss on fake data is 65.61% and 0.618.
# Discriminator class accuracy and loss on fake data is 95.50% and -0.952.
# Generator source accuracy and loss is 31.18% and 1.050.
# Generator class accuracy and loss is 95.59% and -0.953.
#
# Epoch 64:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 66.28% and 0.616.
# Discriminator class accuracy and loss on real data is 55.34% and -1.102.
# Discriminator source accuracy and loss on fake data is 65.75% and 0.617.
# Discriminator class accuracy and loss on fake data is 96.00% and -0.957.
# Generator source accuracy and loss is 31.12% and 1.043.
# Generator class accuracy and loss is 95.98% and -0.957.
#
# Epoch 65:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 66.96% and 0.611.
# Discriminator class accuracy and loss on real data is 55.56% and -1.107.
# Discriminator source accuracy and loss on fake data is 66.45% and 0.612.
# Discriminator class accuracy and loss on fake data is 95.44% and -0.952.
# Generator source accuracy and loss is 29.79% and 1.069.
# Generator class accuracy and loss is 95.74% and -0.955.
#
# Epoch 66:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 66.00% and 0.618.
# Discriminator class accuracy and loss on real data is 55.71% and -1.110.
# Discriminator source accuracy and loss on fake data is 65.28% and 0.619.
# Discriminator class accuracy and loss on fake data is 95.69% and -0.954.
# Generator source accuracy and loss is 30.75% and 1.051.
# Generator class accuracy and loss is 95.66% and -0.953.
#
# Epoch 67:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 66.40% and 0.616.
# Discriminator class accuracy and loss on real data is 55.69% and -1.109.
# Discriminator source accuracy and loss on fake data is 65.91% and 0.618.
# Discriminator class accuracy and loss on fake data is 95.87% and -0.956.
# Generator source accuracy and loss is 31.65% and 1.043.
# Generator class accuracy and loss is 96.04% and -0.957.
#
# Epoch 68:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 66.07% and 0.619.
# Discriminator class accuracy and loss on real data is 55.88% and -1.112.
# Discriminator source accuracy and loss on fake data is 65.80% and 0.618.
# Discriminator class accuracy and loss on fake data is 95.38% and -0.951.
# Generator source accuracy and loss is 31.15% and 1.045.
# Generator class accuracy and loss is 95.28% and -0.950.
#
# Epoch 69:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 66.66% and 0.615.
# Discriminator class accuracy and loss on real data is 56.03% and -1.116.
# Discriminator source accuracy and loss on fake data is 66.15% and 0.614.
# Discriminator class accuracy and loss on fake data is 95.77% and -0.955.
# Generator source accuracy and loss is 31.27% and 1.037.
# Generator class accuracy and loss is 95.80% and -0.955.
#
# Epoch 70:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 66.49% and 0.615.
# Discriminator class accuracy and loss on real data is 55.92% and -1.115.
# Discriminator source accuracy and loss on fake data is 65.62% and 0.617.
# Discriminator class accuracy and loss on fake data is 95.39% and -0.951.
# Generator source accuracy and loss is 31.31% and 1.049.
# Generator class accuracy and loss is 95.60% and -0.953.
#
# Epoch 71:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 67.23% and 0.610.
# Discriminator class accuracy and loss on real data is 56.22% and -1.120.
# Discriminator source accuracy and loss on fake data is 66.36% and 0.611.
# Discriminator class accuracy and loss on fake data is 95.70% and -0.954.
# Generator source accuracy and loss is 31.57% and 1.043.
# Generator class accuracy and loss is 95.75% and -0.955.
#
# Epoch 72:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 66.64% and 0.613.
# Discriminator class accuracy and loss on real data is 56.08% and -1.118.
# Discriminator source accuracy and loss on fake data is 66.07% and 0.614.
# Discriminator class accuracy and loss on fake data is 95.52% and -0.952.
# Generator source accuracy and loss is 30.39% and 1.070.
# Generator class accuracy and loss is 95.62% and -0.953.
#
# Epoch 73:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 67.40% and 0.608.
# Discriminator class accuracy and loss on real data is 56.31% and -1.121.
# Discriminator source accuracy and loss on fake data is 66.71% and 0.609.
# Discriminator class accuracy and loss on fake data is 95.09% and -0.948.
# Generator source accuracy and loss is 30.60% and 1.069.
# Generator class accuracy and loss is 95.41% and -0.951.
#
# Epoch 74:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 66.81% and 0.611.
# Discriminator class accuracy and loss on real data is 56.58% and -1.128.
# Discriminator source accuracy and loss on fake data is 66.21% and 0.611.
# Discriminator class accuracy and loss on fake data is 95.66% and -0.953.
# Generator source accuracy and loss is 30.77% and 1.062.
# Generator class accuracy and loss is 95.54% and -0.953.
#
# Epoch 75:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 67.72% and 0.603.
# Discriminator class accuracy and loss on real data is 56.51% and -1.125.
# Discriminator source accuracy and loss on fake data is 67.13% and 0.604.
# Discriminator class accuracy and loss on fake data is 95.66% and -0.953.
# Generator source accuracy and loss is 31.37% and 1.069.
# Generator class accuracy and loss is 95.59% and -0.953.
#
# Epoch 76:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 66.86% and 0.613.
# Discriminator class accuracy and loss on real data is 56.43% and -1.123.
# Discriminator source accuracy and loss on fake data is 66.37% and 0.613.
# Discriminator class accuracy and loss on fake data is 95.54% and -0.952.
# Generator source accuracy and loss is 31.35% and 1.054.
# Generator class accuracy and loss is 95.29% and -0.950.
#
# Epoch 77:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 66.80% and 0.611.
# Discriminator class accuracy and loss on real data is 56.55% and -1.127.
# Discriminator source accuracy and loss on fake data is 66.49% and 0.612.
# Discriminator class accuracy and loss on fake data is 95.41% and -0.951.
# Generator source accuracy and loss is 31.45% and 1.051.
# Generator class accuracy and loss is 95.50% and -0.952.
#
# Epoch 78:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 66.60% and 0.616.
# Discriminator class accuracy and loss on real data is 56.55% and -1.127.
# Discriminator source accuracy and loss on fake data is 65.59% and 0.620.
# Discriminator class accuracy and loss on fake data is 95.80% and -0.955.
# Generator source accuracy and loss is 31.63% and 1.045.
# Generator class accuracy and loss is 95.74% and -0.955.
#
# Epoch 79:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 66.41% and 0.619.
# Discriminator class accuracy and loss on real data is 57.05% and -1.135.
# Discriminator source accuracy and loss on fake data is 65.73% and 0.618.
# Discriminator class accuracy and loss on fake data is 95.64% and -0.954.
# Generator source accuracy and loss is 31.40% and 1.044.
# Generator class accuracy and loss is 95.80% and -0.955.
#
# Epoch 80:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 66.71% and 0.614.
# Discriminator class accuracy and loss on real data is 56.89% and -1.133.
# Discriminator source accuracy and loss on fake data is 65.88% and 0.616.
# Discriminator class accuracy and loss on fake data is 95.57% and -0.953.
# Generator source accuracy and loss is 30.66% and 1.059.
# Generator class accuracy and loss is 95.47% and -0.952.
#
# Epoch 81:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 66.19% and 0.617.
# Discriminator class accuracy and loss on real data is 57.00% and -1.135.
# Discriminator source accuracy and loss on fake data is 65.51% and 0.619.
# Discriminator class accuracy and loss on fake data is 95.29% and -0.950.
# Generator source accuracy and loss is 31.63% and 1.044.
# Generator class accuracy and loss is 95.40% and -0.951.
#
# Epoch 82:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 67.27% and 0.608.
# Discriminator class accuracy and loss on real data is 57.17% and -1.139.
# Discriminator source accuracy and loss on fake data is 66.19% and 0.610.
# Discriminator class accuracy and loss on fake data is 95.41% and -0.951.
# Generator source accuracy and loss is 30.57% and 1.062.
# Generator class accuracy and loss is 95.65% and -0.953.
#
# Epoch 83:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 66.21% and 0.619.
# Discriminator class accuracy and loss on real data is 56.93% and -1.134.
# Discriminator source accuracy and loss on fake data is 65.55% and 0.618.
# Discriminator class accuracy and loss on fake data is 95.31% and -0.950.
# Generator source accuracy and loss is 32.28% and 1.035.
# Generator class accuracy and loss is 95.60% and -0.953.
#
# Epoch 84:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 66.45% and 0.615.
# Discriminator class accuracy and loss on real data is 57.36% and -1.142.
# Discriminator source accuracy and loss on fake data is 66.05% and 0.613.
# Discriminator class accuracy and loss on fake data is 95.47% and -0.952.
# Generator source accuracy and loss is 30.13% and 1.068.
# Generator class accuracy and loss is 95.60% and -0.953.
#
# Epoch 85:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 66.97% and 0.610.
# Discriminator class accuracy and loss on real data is 57.60% and -1.147.
# Discriminator source accuracy and loss on fake data is 66.12% and 0.610.
# Discriminator class accuracy and loss on fake data is 95.75% and -0.954.
# Generator source accuracy and loss is 30.95% and 1.047.
# Generator class accuracy and loss is 95.70% and -0.954.
#
# Epoch 86:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 67.37% and 0.607.
# Discriminator class accuracy and loss on real data is 57.74% and -1.150.
# Discriminator source accuracy and loss on fake data is 66.37% and 0.610.
# Discriminator class accuracy and loss on fake data is 95.78% and -0.955.
# Generator source accuracy and loss is 31.61% and 1.043.
# Generator class accuracy and loss is 95.76% and -0.955.
#
# Epoch 87:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 66.37% and 0.619.
# Discriminator class accuracy and loss on real data is 57.46% and -1.146.
# Discriminator source accuracy and loss on fake data is 65.32% and 0.620.
# Discriminator class accuracy and loss on fake data is 95.25% and -0.949.
# Generator source accuracy and loss is 31.42% and 1.049.
# Generator class accuracy and loss is 95.23% and -0.949.
#
# Epoch 88:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 66.85% and 0.614.
# Discriminator class accuracy and loss on real data is 57.53% and -1.146.
# Discriminator source accuracy and loss on fake data is 66.23% and 0.614.
# Discriminator class accuracy and loss on fake data is 95.51% and -0.952.
# Generator source accuracy and loss is 30.38% and 1.061.
# Generator class accuracy and loss is 95.60% and -0.953.
#
# Epoch 89:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 67.18% and 0.608.
# Discriminator class accuracy and loss on real data is 57.93% and -1.154.
# Discriminator source accuracy and loss on fake data is 66.12% and 0.609.
# Discriminator class accuracy and loss on fake data is 95.45% and -0.952.
# Generator source accuracy and loss is 31.90% and 1.038.
# Generator class accuracy and loss is 95.56% and -0.953.
#
# Epoch 90:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 66.86% and 0.610.
# Discriminator class accuracy and loss on real data is 57.60% and -1.148.
# Discriminator source accuracy and loss on fake data is 66.50% and 0.609.
# Discriminator class accuracy and loss on fake data is 95.22% and -0.949.
# Generator source accuracy and loss is 30.15% and 1.075.
# Generator class accuracy and loss is 95.26% and -0.950.
#
# Epoch 91:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 67.67% and 0.605.
# Discriminator class accuracy and loss on real data is 57.55% and -1.147.
# Discriminator source accuracy and loss on fake data is 66.83% and 0.605.
# Discriminator class accuracy and loss on fake data is 95.67% and -0.954.
# Generator source accuracy and loss is 31.65% and 1.052.
# Generator class accuracy and loss is 95.67% and -0.954.
#
# Epoch 92:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 68.14% and 0.600.
# Discriminator class accuracy and loss on real data is 57.93% and -1.153.
# Discriminator source accuracy and loss on fake data is 67.06% and 0.603.
# Discriminator class accuracy and loss on fake data is 95.40% and -0.951.
# Generator source accuracy and loss is 29.96% and 1.085.
# Generator class accuracy and loss is 95.42% and -0.951.
#
# Epoch 93:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 66.97% and 0.610.
# Discriminator class accuracy and loss on real data is 57.77% and -1.152.
# Discriminator source accuracy and loss on fake data is 66.23% and 0.612.
# Discriminator class accuracy and loss on fake data is 95.35% and -0.951.
# Generator source accuracy and loss is 31.73% and 1.054.
# Generator class accuracy and loss is 95.58% and -0.953.
#
# Epoch 94:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 67.40% and 0.609.
# Discriminator class accuracy and loss on real data is 57.84% and -1.152.
# Discriminator source accuracy and loss on fake data is 66.73% and 0.608.
# Discriminator class accuracy and loss on fake data is 95.33% and -0.950.
# Generator source accuracy and loss is 31.49% and 1.062.
# Generator class accuracy and loss is 95.28% and -0.950.
#
# Epoch 95:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 67.24% and 0.608.
# Discriminator class accuracy and loss on real data is 58.07% and -1.157.
# Discriminator source accuracy and loss on fake data is 66.30% and 0.610.
# Discriminator class accuracy and loss on fake data is 95.24% and -0.950.
# Generator source accuracy and loss is 30.43% and 1.074.
# Generator class accuracy and loss is 95.33% and -0.951.
#
# Epoch 96:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 67.11% and 0.608.
# Discriminator class accuracy and loss on real data is 57.94% and -1.155.
# Discriminator source accuracy and loss on fake data is 66.68% and 0.607.
# Discriminator class accuracy and loss on fake data is 95.01% and -0.947.
# Generator source accuracy and loss is 31.63% and 1.057.
# Generator class accuracy and loss is 95.12% and -0.949.
#
# Epoch 97:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 67.65% and 0.605.
# Discriminator class accuracy and loss on real data is 58.01% and -1.155.
# Discriminator source accuracy and loss on fake data is 66.69% and 0.606.
# Discriminator class accuracy and loss on fake data is 95.07% and -0.948.
# Generator source accuracy and loss is 31.51% and 1.061.
# Generator class accuracy and loss is 95.31% and -0.950.
#
# Epoch 98:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 66.93% and 0.611.
# Discriminator class accuracy and loss on real data is 57.84% and -1.152.
# Discriminator source accuracy and loss on fake data is 66.11% and 0.613.
# Discriminator class accuracy and loss on fake data is 95.44% and -0.951.
# Generator source accuracy and loss is 31.34% and 1.063.
# Generator class accuracy and loss is 95.34% and -0.951.
#
# Epoch 99:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 67.20% and 0.606.
# Discriminator class accuracy and loss on real data is 57.95% and -1.153.
# Discriminator source accuracy and loss on fake data is 66.34% and 0.609.
# Discriminator class accuracy and loss on fake data is 95.06% and -0.948.
# Generator source accuracy and loss is 30.49% and 1.072.
# Generator class accuracy and loss is 95.10% and -0.948.

# %%
data = np.r_[np.array(d_real_source_accuracies_avg),
      np.array(d_real_class_accuracies_avg),
      np.array(d_real_source_losses_avg),
      np.array(d_real_class_losses_avg),
      np.array(d_fake_source_accuracies_avg),
      np.array(d_fake_class_accuracies_avg),
      np.array(d_fake_source_losses_avg),
      np.array(d_fake_class_losses_avg),
      np.array(g_source_accuracies_avg),
      np.array(g_class_accuracies_avg),
      np.array(g_source_losses_avg),
      np.array(g_class_losses_avg)]

# %%
pd.DataFrame(data).to_csv("data_original.csv")
