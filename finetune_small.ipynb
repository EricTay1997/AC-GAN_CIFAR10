# %%
import torch
import torchvision.transforms as transforms
import torchvision
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from resnet20 import ResNetCIFAR

# %%
transform_train = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
])

# %%
trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform_train)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=100, shuffle=True, num_workers=2)
# Out:
# Files already downloaded and verified

# %%
class Generator(nn.Module):
    def __init__(self):
        super(Generator, self).__init__()
        self.fc1 = nn.Sequential(
            nn.Linear(110,384),
            nn.ReLU())
        self.tconv1 = nn.Sequential(
            nn.ConvTranspose2d(384, 192, 6, 2),
            nn.BatchNorm2d(192),
            nn.ReLU())
        self.tconv2 = nn.Sequential(
            nn.ConvTranspose2d(192, 96, 5, 2),
            nn.BatchNorm2d(96),
            nn.ReLU())
        self.tconv3 = nn.Sequential(
            nn.ConvTranspose2d(96, 3, 4, 2),
            nn.Tanh())
        self._initialize_weights()
    
    def forward(self, x):
        out = self.fc1(x)
        out = self.tconv1(out[:,:,None,None])
        out = self.tconv2(out)
        out = self.tconv3(out)
        return out
    
    def _initialize_weights(self):
        for m in self.modules():
            if isinstance(m, nn.ConvTranspose2d) or isinstance(m, nn.Linear):
                m.weight.data.normal_(0, 0.01)
                m.bias.data.zero_()
            elif isinstance(m, nn.BatchNorm2d):
                m.weight.data.fill_(1)
                m.bias.data.zero_()

# %%
class Discriminator(nn.Module):
    
    def __init__(self):
        super(Discriminator, self).__init__()
        self.conv1 = nn.Sequential(
            nn.Conv2d(3, 16, 3, 2, 1),
            nn.LeakyReLU(0.2))
        self.conv2 = nn.Sequential(
            nn.Conv2d(16, 32, 3, 1, 1),
            nn.BatchNorm2d(32),
            nn.LeakyReLU(0.2))
        self.conv3 = nn.Sequential(
            nn.Conv2d(32, 64, 3, 2, 1),
            nn.BatchNorm2d(64),
            nn.LeakyReLU(0.2))
        self.conv4 = nn.Sequential(
            nn.Conv2d(64, 128, 3, 1, 1),
            nn.BatchNorm2d(128),
            nn.LeakyReLU(0.2))
        self.conv5 = nn.Sequential(
            nn.Conv2d(128, 256, 3, 2, 1),
            nn.BatchNorm2d(256),
            nn.LeakyReLU(0.2))
        self.conv6 = nn.Sequential(
            nn.Conv2d(256, 512, 3, 1, 1),
            nn.BatchNorm2d(512),
            nn.LeakyReLU(0.2))
        self.dropout = nn.Dropout(0.5)
        self.activation_noise_sd = 0.1
        self.fc = nn.Linear(4*4*512, 11)
        self.sigmoid = nn.Sigmoid()
        self.softmax = nn.Softmax(1)
        self._initialize_weights()

    def forward(self,x):
        out = self.conv1(x)
        out = self.dropout(out + self.activation_noise_sd*torch.rand(out.shape).to(device))
        out = self.conv2(out)
        out = self.dropout(out + self.activation_noise_sd*torch.rand(out.shape).to(device))
        out = self.conv3(out)
        out = self.dropout(out + self.activation_noise_sd*torch.rand(out.shape).to(device))
        out = self.conv4(out)
        out = self.dropout(out + self.activation_noise_sd*torch.rand(out.shape).to(device))
        out = self.conv5(out)
        out = self.dropout(out + self.activation_noise_sd*torch.rand(out.shape).to(device))
        out = self.conv6(out)
        out = self.dropout(out + self.activation_noise_sd*torch.rand(out.shape).to(device))
        out = self.fc(out.reshape(-1,4*4*512))
        return self.sigmoid(out[:,0]), self.softmax(out[:,1:])
    
    def _initialize_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Conv2d) or isinstance(m, nn.Linear):
                m.weight.data.normal_(0, 0.01)
                m.bias.data.zero_()
            elif isinstance(m, nn.BatchNorm2d):
                m.weight.data.fill_(1)
                m.bias.data.zero_()

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
generator = Generator()
generator = generator.to(device)
discriminator = Discriminator()
discriminator = discriminator.to(device)

# %%
optimizer_d = optim.Adam(discriminator.parameters(), lr = 0.0001, betas = (0.5, 0.999))
optimizer_g = optim.Adam(generator.parameters(), lr = 0.0001, betas = (0.5, 0.999))
criterion_source = nn.BCELoss()
criterion_class = nn.NLLLoss()

# %%
generator.load_state_dict(torch.load("generator100_original.pt"))
discriminator.load_state_dict(torch.load("discriminator100_original.pt"))
# Out:
# <All keys matched successfully>

# %%
def reverse_norm_fake_image(img):
    return img*0.5 + 0.5

def norm_orig_image(img):
    return (img - torch.tensor([0.4914, 0.4822, 0.4465])[None,:,None,None])/torch.tensor([0.2023, 0.1994, 0.2010])[None,:,None,None]

# %%
net = ResNetCIFAR(num_layers=20)
net = net.to(device)
net.load_state_dict(torch.load("net_before_pruning.pt"))
# Out:
# <All keys matched successfully>

# %%
def calculate_inception_score(preds, splits = 10):
    preds = np.exp(preds)
    preds /= preds.sum(axis = 1)[:, None]
    scores = []
    for i in range(splits):
        split = preds[i*preds.shape[0]//splits : (i+1)*preds.shape[0]//splits, :]
        kl = split*(np.log(split) - np.log(np.mean(split, axis = 0)))
        scores.append(np.exp(np.mean(np.sum(kl, 1))))
    return np.mean(scores), np.std(scores)

# %%
max_inception_score = 0
for epoch in range(100, 160):
    print("Epoch {}:".format(epoch))
    
    d_real_source_accuracies = []
    d_real_class_accuracies = []
    d_real_source_losses = []
    d_real_class_losses = []
    d_fake_source_accuracies = []
    d_fake_class_accuracies = []
    d_fake_source_losses = [] 
    d_fake_class_losses = []
    g_source_accuracies = []
    g_class_accuracies = []
    g_source_losses = []
    g_class_losses = []
    
    for batch_idx, (inputs, targets) in enumerate(trainloader):
        if batch_idx % 100 == 0:
            print("Batch Index: {}".format(batch_idx))
        # Train discriminator with real data
        inputs, targets = inputs.to(device), targets.to(device)
        optimizer_d.zero_grad()
        sources, classes = discriminator(inputs)
        source_targets = torch.ones(sources.shape).to(device)
        source_loss = criterion_source(sources, source_targets)
        class_loss = 10*criterion_class(classes, targets)
        d_real_loss = (source_loss + class_loss)/2
        d_real_loss.backward()
        # optimizer_d.step()
        d_real_source_accuracy = torch.mean((torch.where(sources > 0.5, torch.tensor(1.).to(device), torch.tensor(0.).to(device)) == source_targets).float()).item()*100
        d_real_class_accuracy = torch.mean((classes.max(1)[1] == targets).float()).item()*100
        d_real_source_accuracies.append(d_real_source_accuracy)
        d_real_class_accuracies.append(d_real_class_accuracy)
        d_real_source_losses.append(source_loss.item())
        d_real_class_losses.append(class_loss.item())
        
        # Train discriminator with fake data
        fake_targets = np.random.randint(0, 10, inputs.shape[0])
        gen_input_np = np.c_[np.random.randn(inputs.shape[0], 100), np.eye(10)[fake_targets]]
        fake_targets = torch.from_numpy(fake_targets).long().to(device)
        gen_input = torch.from_numpy(gen_input_np).float().to(device)
        fake_inputs = generator(gen_input)
        # optimizer_d.zero_grad()
        sources, classes = discriminator(fake_inputs.detach())
        source_targets = torch.zeros(sources.shape).to(device)
        source_loss = criterion_source(sources, source_targets) 
        class_loss = criterion_class(classes, fake_targets)
        d_fake_loss = (source_loss + class_loss)/2
        d_fake_loss.backward()
        optimizer_d.step()
        d_fake_source_accuracy = np.round(torch.mean((torch.where(sources > 0.5, torch.tensor(1.).to(device), torch.tensor(0.).to(device)) == source_targets).float()).item()*100)
        d_fake_class_accuracy = np.round(torch.mean((classes.max(1)[1] == fake_targets).float()).item()*100)
        d_fake_source_accuracies.append(d_fake_source_accuracy)
        d_fake_class_accuracies.append(d_fake_class_accuracy)
        d_fake_source_losses.append(source_loss.item())
        d_fake_class_losses.append(class_loss.item())
        
        # Train generator
        optimizer_g.zero_grad()
        sources, classes = discriminator(fake_inputs)
        source_targets = torch.ones(sources.shape).to(device)
        source_loss = criterion_source(sources, source_targets) 
        class_loss = criterion_class(classes, fake_targets)
        g_loss = source_loss + class_loss
        g_loss.backward()
        optimizer_g.step()
        g_source_accuracy = np.round(torch.mean((torch.where(sources > 0.5, torch.tensor(1.).to(device), torch.tensor(0.).to(device)) == source_targets).float()).item()*100)
        g_class_accuracy = np.round(torch.mean((classes.max(1)[1] == fake_targets).float()).item()*100)
        g_source_accuracies.append(g_source_accuracy)
        g_class_accuracies.append(g_class_accuracy)
        g_source_losses.append(source_loss.item())
        g_class_losses.append(class_loss.item())

    print("Discriminator source accuracy and loss on real data is {:.2f}% and {:.3f}.".format(np.mean(d_real_source_accuracies), np.mean(d_real_source_losses)))
    print("Discriminator class accuracy and loss on real data is {:.2f}% and {:.3f}.".format(np.mean(d_real_class_accuracies), np.mean(d_real_class_losses)))
    print("Discriminator source accuracy and loss on fake data is {:.2f}% and {:.3f}.".format(np.mean(d_fake_source_accuracies), np.mean(d_fake_source_losses)))
    print("Discriminator class accuracy and loss on fake data is {:.2f}% and {:.3f}.".format(np.mean(d_fake_class_accuracies), np.mean(d_fake_class_losses)))
    print("Generator source accuracy and loss is {:.2f}% and {:.3f}.".format(np.mean(g_source_accuracies), np.mean(g_source_losses)))
    print("Generator class accuracy and loss is {:.2f}% and {:.3f}.".format(np.mean(g_class_accuracies), np.mean(g_class_losses)))

    fakes = []
    for i in range(100):
        fake_targets = np.random.randint(0, 10, 100)
        gen_input_np = np.c_[np.random.randn(100, 100), np.eye(10)[fake_targets]]
        gen_input = torch.from_numpy(gen_input_np).float().to(device)
        fake_inputs = generator(gen_input)
        fakes.append((reverse_norm_fake_image(fake_inputs.detach().cpu()), fake_targets))

    net.eval()
    preds = np.empty((0,10))
    all_targets = np.empty((0,100))
    for batch_idx, (inputs, targets) in enumerate(fakes):
        inputs = norm_orig_image(inputs).to(device)
        output = net(inputs)
        preds = np.r_[preds, output.detach().cpu().numpy()]
        all_targets = np.r_[all_targets, targets[None, :]]

    inception_score = calculate_inception_score(preds)[0]

    print("Resnet Accuracy: {}".format(np.mean(np.argmax(preds, axis = 1) == all_targets.flatten())))
    print("Inception Score: {}\n".format(inception_score))

    if inception_score > max_inception_score:
        max_inception_score = inception_score
        torch.save(generator.state_dict(), "generator160_small.pt")
        torch.save(discriminator.state_dict(), "discriminator160_small.pt")
# Out:
# Epoch 100:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 64.26% and 0.638.
# Discriminator class accuracy and loss on real data is 58.62% and -5.843.
# Discriminator source accuracy and loss on fake data is 63.16% and 0.642.
# Discriminator class accuracy and loss on fake data is 95.06% and -0.948.
# Generator source accuracy and loss is 36.75% and 0.958.
# Generator class accuracy and loss is 95.05% and -0.948.
# Resnet Accuracy: 0.4963
# Inception Score: 4.247519170711181
#
# Epoch 101:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 60.48% and 0.670.
# Discriminator class accuracy and loss on real data is 59.13% and -5.886.
# Discriminator source accuracy and loss on fake data is 59.93% and 0.671.
# Discriminator class accuracy and loss on fake data is 95.52% and -0.952.
# Generator source accuracy and loss is 39.91% and 0.895.
# Generator class accuracy and loss is 95.51% and -0.953.
# Resnet Accuracy: 0.4956
# Inception Score: 4.077669241512683
#
# Epoch 102:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 61.37% and 0.662.
# Discriminator class accuracy and loss on real data is 59.69% and -5.939.
# Discriminator source accuracy and loss on fake data is 60.46% and 0.664.
# Discriminator class accuracy and loss on fake data is 95.64% and -0.954.
# Generator source accuracy and loss is 39.78% and 0.894.
# Generator class accuracy and loss is 95.79% and -0.955.
# Resnet Accuracy: 0.4444
# Inception Score: 3.814447750887646
#
# Epoch 103:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 62.02% and 0.656.
# Discriminator class accuracy and loss on real data is 59.58% and -5.940.
# Discriminator source accuracy and loss on fake data is 61.38% and 0.656.
# Discriminator class accuracy and loss on fake data is 96.38% and -0.961.
# Generator source accuracy and loss is 38.08% and 0.897.
# Generator class accuracy and loss is 96.11% and -0.958.
# Resnet Accuracy: 0.4321
# Inception Score: 3.9106088798025107
#
# Epoch 104:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 61.71% and 0.658.
# Discriminator class accuracy and loss on real data is 60.04% and -5.979.
# Discriminator source accuracy and loss on fake data is 60.68% and 0.658.
# Discriminator class accuracy and loss on fake data is 95.93% and -0.957.
# Generator source accuracy and loss is 37.98% and 0.889.
# Generator class accuracy and loss is 96.20% and -0.959.
# Resnet Accuracy: 0.458
# Inception Score: 3.983457081908116
#
# Epoch 105:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 61.12% and 0.662.
# Discriminator class accuracy and loss on real data is 60.29% and -6.003.
# Discriminator source accuracy and loss on fake data is 60.32% and 0.662.
# Discriminator class accuracy and loss on fake data is 95.97% and -0.957.
# Generator source accuracy and loss is 40.30% and 0.867.
# Generator class accuracy and loss is 96.11% and -0.958.
# Resnet Accuracy: 0.4372
# Inception Score: 3.908259933889114
#
# Epoch 106:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 61.15% and 0.661.
# Discriminator class accuracy and loss on real data is 60.35% and -6.014.
# Discriminator source accuracy and loss on fake data is 60.08% and 0.664.
# Discriminator class accuracy and loss on fake data is 96.26% and -0.961.
# Generator source accuracy and loss is 39.44% and 0.865.
# Generator class accuracy and loss is 96.40% and -0.961.
# Resnet Accuracy: 0.4226
# Inception Score: 3.800971502876019
#
# Epoch 107:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 60.54% and 0.665.
# Discriminator class accuracy and loss on real data is 60.89% and -6.064.
# Discriminator source accuracy and loss on fake data is 59.59% and 0.666.
# Discriminator class accuracy and loss on fake data is 96.20% and -0.960.
# Generator source accuracy and loss is 40.61% and 0.847.
# Generator class accuracy and loss is 96.28% and -0.960.
# Resnet Accuracy: 0.4408
# Inception Score: 3.7226248475442185
#
# Epoch 108:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 60.32% and 0.665.
# Discriminator class accuracy and loss on real data is 60.58% and -6.043.
# Discriminator source accuracy and loss on fake data is 59.41% and 0.667.
# Discriminator class accuracy and loss on fake data is 96.14% and -0.959.
# Generator source accuracy and loss is 40.23% and 0.846.
# Generator class accuracy and loss is 96.25% and -0.960.
# Resnet Accuracy: 0.391
# Inception Score: 3.4644962279974805
#
# Epoch 109:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 59.95% and 0.668.
# Discriminator class accuracy and loss on real data is 60.85% and -6.064.
# Discriminator source accuracy and loss on fake data is 58.56% and 0.673.
# Discriminator class accuracy and loss on fake data is 96.27% and -0.960.
# Generator source accuracy and loss is 40.24% and 0.839.
# Generator class accuracy and loss is 96.35% and -0.961.
# Resnet Accuracy: 0.4414
# Inception Score: 3.8696022417176663
#
# Epoch 110:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 59.94% and 0.668.
# Discriminator class accuracy and loss on real data is 60.98% and -6.075.
# Discriminator source accuracy and loss on fake data is 59.43% and 0.667.
# Discriminator class accuracy and loss on fake data is 96.49% and -0.963.
# Generator source accuracy and loss is 40.23% and 0.833.
# Generator class accuracy and loss is 96.52% and -0.963.
# Resnet Accuracy: 0.4526
# Inception Score: 3.8865016060009205
#
# Epoch 111:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 60.13% and 0.665.
# Discriminator class accuracy and loss on real data is 61.18% and -6.097.
# Discriminator source accuracy and loss on fake data is 59.54% and 0.667.
# Discriminator class accuracy and loss on fake data is 96.79% and -0.966.
# Generator source accuracy and loss is 39.84% and 0.835.
# Generator class accuracy and loss is 96.80% and -0.966.
# Resnet Accuracy: 0.4428
# Inception Score: 3.8964370466333156
#
# Epoch 112:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 59.55% and 0.669.
# Discriminator class accuracy and loss on real data is 61.54% and -6.133.
# Discriminator source accuracy and loss on fake data is 58.41% and 0.674.
# Discriminator class accuracy and loss on fake data is 97.19% and -0.970.
# Generator source accuracy and loss is 41.76% and 0.814.
# Generator class accuracy and loss is 97.21% and -0.969.
# Resnet Accuracy: 0.4908
# Inception Score: 4.262773770669657
#
# Epoch 113:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 59.60% and 0.668.
# Discriminator class accuracy and loss on real data is 60.99% and -6.072.
# Discriminator source accuracy and loss on fake data is 58.37% and 0.674.
# Discriminator class accuracy and loss on fake data is 97.07% and -0.969.
# Generator source accuracy and loss is 41.38% and 0.814.
# Generator class accuracy and loss is 97.05% and -0.968.
# Resnet Accuracy: 0.4723
# Inception Score: 4.290483366326228
#
# Epoch 114:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 59.10% and 0.672.
# Discriminator class accuracy and loss on real data is 61.60% and -6.138.
# Discriminator source accuracy and loss on fake data is 58.23% and 0.674.
# Discriminator class accuracy and loss on fake data is 97.43% and -0.972.
# Generator source accuracy and loss is 41.60% and 0.804.
# Generator class accuracy and loss is 97.36% and -0.972.
# Resnet Accuracy: 0.4441
# Inception Score: 3.8872022471653422
#
# Epoch 115:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 58.52% and 0.675.
# Discriminator class accuracy and loss on real data is 61.64% and -6.143.
# Discriminator source accuracy and loss on fake data is 58.23% and 0.673.
# Discriminator class accuracy and loss on fake data is 97.19% and -0.970.
# Generator source accuracy and loss is 40.59% and 0.810.
# Generator class accuracy and loss is 97.42% and -0.972.
# Resnet Accuracy: 0.4338
# Inception Score: 3.700618855463669
#
# Epoch 116:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 59.42% and 0.670.
# Discriminator class accuracy and loss on real data is 61.94% and -6.168.
# Discriminator source accuracy and loss on fake data is 58.20% and 0.671.
# Discriminator class accuracy and loss on fake data is 97.41% and -0.972.
# Generator source accuracy and loss is 41.30% and 0.801.
# Generator class accuracy and loss is 97.30% and -0.971.
# Resnet Accuracy: 0.4772
# Inception Score: 4.02119480216449
#
# Epoch 117:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 58.55% and 0.675.
# Discriminator class accuracy and loss on real data is 61.96% and -6.170.
# Discriminator source accuracy and loss on fake data is 57.57% and 0.677.
# Discriminator class accuracy and loss on fake data is 97.31% and -0.971.
# Generator source accuracy and loss is 41.83% and 0.795.
# Generator class accuracy and loss is 97.39% and -0.972.
# Resnet Accuracy: 0.4786
# Inception Score: 3.896645313086238
#
# Epoch 118:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 58.66% and 0.674.
# Discriminator class accuracy and loss on real data is 61.82% and -6.162.
# Discriminator source accuracy and loss on fake data is 57.24% and 0.679.
# Discriminator class accuracy and loss on fake data is 97.67% and -0.975.
# Generator source accuracy and loss is 42.50% and 0.787.
# Generator class accuracy and loss is 97.68% and -0.974.
# Resnet Accuracy: 0.4627
# Inception Score: 3.903177237441567
#
# Epoch 119:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 59.17% and 0.670.
# Discriminator class accuracy and loss on real data is 62.02% and -6.181.
# Discriminator source accuracy and loss on fake data is 58.33% and 0.673.
# Discriminator class accuracy and loss on fake data is 97.62% and -0.974.
# Generator source accuracy and loss is 41.12% and 0.795.
# Generator class accuracy and loss is 97.53% and -0.973.
# Resnet Accuracy: 0.4844
# Inception Score: 3.9470782040291468
#
# Epoch 120:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 57.85% and 0.678.
# Discriminator class accuracy and loss on real data is 62.19% and -6.196.
# Discriminator source accuracy and loss on fake data is 57.53% and 0.677.
# Discriminator class accuracy and loss on fake data is 97.61% and -0.974.
# Generator source accuracy and loss is 42.44% and 0.784.
# Generator class accuracy and loss is 97.64% and -0.974.
# Resnet Accuracy: 0.5007
# Inception Score: 4.0326912067550875
#
# Epoch 121:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 59.09% and 0.672.
# Discriminator class accuracy and loss on real data is 62.46% and -6.212.
# Discriminator source accuracy and loss on fake data is 58.01% and 0.674.
# Discriminator class accuracy and loss on fake data is 97.80% and -0.976.
# Generator source accuracy and loss is 41.96% and 0.787.
# Generator class accuracy and loss is 97.70% and -0.975.
# Resnet Accuracy: 0.4826
# Inception Score: 4.0675540218684985
#
# Epoch 122:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 58.32% and 0.675.
# Discriminator class accuracy and loss on real data is 62.31% and -6.208.
# Discriminator source accuracy and loss on fake data is 57.19% and 0.679.
# Discriminator class accuracy and loss on fake data is 97.71% and -0.975.
# Generator source accuracy and loss is 42.45% and 0.783.
# Generator class accuracy and loss is 97.61% and -0.975.
# Resnet Accuracy: 0.5472
# Inception Score: 4.290318541960279
#
# Epoch 123:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 58.32% and 0.674.
# Discriminator class accuracy and loss on real data is 62.37% and -6.209.
# Discriminator source accuracy and loss on fake data is 57.47% and 0.676.
# Discriminator class accuracy and loss on fake data is 97.61% and -0.974.
# Generator source accuracy and loss is 42.85% and 0.779.
# Generator class accuracy and loss is 97.67% and -0.975.
# Resnet Accuracy: 0.5518
# Inception Score: 4.302169773746499
#
# Epoch 124:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 58.44% and 0.675.
# Discriminator class accuracy and loss on real data is 62.80% and -6.255.
# Discriminator source accuracy and loss on fake data is 57.48% and 0.676.
# Discriminator class accuracy and loss on fake data is 97.70% and -0.975.
# Generator source accuracy and loss is 41.89% and 0.783.
# Generator class accuracy and loss is 97.68% and -0.975.
# Resnet Accuracy: 0.5505
# Inception Score: 4.25718569400224
#
# Epoch 125:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 57.78% and 0.677.
# Discriminator class accuracy and loss on real data is 62.63% and -6.242.
# Discriminator source accuracy and loss on fake data is 56.84% and 0.680.
# Discriminator class accuracy and loss on fake data is 97.82% and -0.977.
# Generator source accuracy and loss is 42.40% and 0.778.
# Generator class accuracy and loss is 97.81% and -0.976.
# Resnet Accuracy: 0.5574
# Inception Score: 4.31765816277206
#
# Epoch 126:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 58.21% and 0.676.
# Discriminator class accuracy and loss on real data is 62.86% and -6.260.
# Discriminator source accuracy and loss on fake data is 56.92% and 0.679.
# Discriminator class accuracy and loss on fake data is 97.83% and -0.977.
# Generator source accuracy and loss is 42.46% and 0.773.
# Generator class accuracy and loss is 97.84% and -0.977.
# Resnet Accuracy: 0.5743
# Inception Score: 4.3566572995929365
#
# Epoch 127:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 58.13% and 0.676.
# Discriminator class accuracy and loss on real data is 62.48% and -6.222.
# Discriminator source accuracy and loss on fake data is 57.06% and 0.679.
# Discriminator class accuracy and loss on fake data is 97.94% and -0.978.
# Generator source accuracy and loss is 42.44% and 0.774.
# Generator class accuracy and loss is 97.89% and -0.977.
# Resnet Accuracy: 0.5882
# Inception Score: 4.702733108303415
#
# Epoch 128:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 57.86% and 0.678.
# Discriminator class accuracy and loss on real data is 63.03% and -6.275.
# Discriminator source accuracy and loss on fake data is 56.84% and 0.680.
# Discriminator class accuracy and loss on fake data is 98.04% and -0.979.
# Generator source accuracy and loss is 42.82% and 0.771.
# Generator class accuracy and loss is 97.89% and -0.977.
# Resnet Accuracy: 0.58
# Inception Score: 4.630090239742459
#
# Epoch 129:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 58.17% and 0.675.
# Discriminator class accuracy and loss on real data is 62.94% and -6.271.
# Discriminator source accuracy and loss on fake data is 57.18% and 0.677.
# Discriminator class accuracy and loss on fake data is 97.99% and -0.978.
# Generator source accuracy and loss is 43.13% and 0.768.
# Generator class accuracy and loss is 98.03% and -0.978.
# Resnet Accuracy: 0.5838
# Inception Score: 4.6253682155917115
#
# Epoch 130:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 57.65% and 0.676.
# Discriminator class accuracy and loss on real data is 63.18% and -6.296.
# Discriminator source accuracy and loss on fake data is 56.97% and 0.679.
# Discriminator class accuracy and loss on fake data is 97.99% and -0.978.
# Generator source accuracy and loss is 42.68% and 0.771.
# Generator class accuracy and loss is 97.88% and -0.977.
# Resnet Accuracy: 0.6002
# Inception Score: 4.798405559495775
#
# Epoch 131:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 57.37% and 0.680.
# Discriminator class accuracy and loss on real data is 63.13% and -6.283.
# Discriminator source accuracy and loss on fake data is 56.69% and 0.679.
# Discriminator class accuracy and loss on fake data is 97.91% and -0.977.
# Generator source accuracy and loss is 41.99% and 0.773.
# Generator class accuracy and loss is 97.92% and -0.978.
# Resnet Accuracy: 0.6002
# Inception Score: 4.717694651844051
#
# Epoch 132:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 57.64% and 0.678.
# Discriminator class accuracy and loss on real data is 63.16% and -6.291.
# Discriminator source accuracy and loss on fake data is 56.31% and 0.682.
# Discriminator class accuracy and loss on fake data is 97.94% and -0.978.
# Generator source accuracy and loss is 43.60% and 0.761.
# Generator class accuracy and loss is 97.93% and -0.978.
# Resnet Accuracy: 0.5739
# Inception Score: 4.506318981434765
#
# Epoch 133:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 57.72% and 0.677.
# Discriminator class accuracy and loss on real data is 63.06% and -6.282.
# Discriminator source accuracy and loss on fake data is 56.48% and 0.681.
# Discriminator class accuracy and loss on fake data is 97.99% and -0.978.
# Generator source accuracy and loss is 43.39% and 0.763.
# Generator class accuracy and loss is 98.05% and -0.979.
# Resnet Accuracy: 0.6273
# Inception Score: 4.969534892954522
#
# Epoch 134:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 57.22% and 0.681.
# Discriminator class accuracy and loss on real data is 63.28% and -6.302.
# Discriminator source accuracy and loss on fake data is 56.95% and 0.678.
# Discriminator class accuracy and loss on fake data is 98.32% and -0.982.
# Generator source accuracy and loss is 42.72% and 0.765.
# Generator class accuracy and loss is 98.31% and -0.981.
# Resnet Accuracy: 0.6354
# Inception Score: 4.982539631251223
#
# Epoch 135:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 56.68% and 0.683.
# Discriminator class accuracy and loss on real data is 63.41% and -6.318.
# Discriminator source accuracy and loss on fake data is 56.27% and 0.683.
# Discriminator class accuracy and loss on fake data is 98.19% and -0.980.
# Generator source accuracy and loss is 43.51% and 0.759.
# Generator class accuracy and loss is 98.13% and -0.980.
# Resnet Accuracy: 0.6332
# Inception Score: 4.934752848215867
#
# Epoch 136:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 57.47% and 0.678.
# Discriminator class accuracy and loss on real data is 63.71% and -6.344.
# Discriminator source accuracy and loss on fake data is 56.54% and 0.681.
# Discriminator class accuracy and loss on fake data is 98.14% and -0.980.
# Generator source accuracy and loss is 42.77% and 0.761.
# Generator class accuracy and loss is 98.17% and -0.980.
# Resnet Accuracy: 0.6191
# Inception Score: 4.86633891652063
#
# Epoch 137:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 57.49% and 0.678.
# Discriminator class accuracy and loss on real data is 63.67% and -6.340.
# Discriminator source accuracy and loss on fake data is 56.51% and 0.679.
# Discriminator class accuracy and loss on fake data is 98.27% and -0.981.
# Generator source accuracy and loss is 42.51% and 0.765.
# Generator class accuracy and loss is 98.21% and -0.981.
# Resnet Accuracy: 0.6001
# Inception Score: 4.666211998364946
#
# Epoch 138:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 57.07% and 0.682.
# Discriminator class accuracy and loss on real data is 63.43% and -6.322.
# Discriminator source accuracy and loss on fake data is 56.09% and 0.682.
# Discriminator class accuracy and loss on fake data is 98.01% and -0.979.
# Generator source accuracy and loss is 43.35% and 0.758.
# Generator class accuracy and loss is 98.06% and -0.979.
# Resnet Accuracy: 0.5901
# Inception Score: 4.640265437067271
#
# Epoch 139:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 57.25% and 0.681.
# Discriminator class accuracy and loss on real data is 63.83% and -6.357.
# Discriminator source accuracy and loss on fake data is 56.14% and 0.683.
# Discriminator class accuracy and loss on fake data is 97.99% and -0.978.
# Generator source accuracy and loss is 44.25% and 0.753.
# Generator class accuracy and loss is 98.07% and -0.979.
# Resnet Accuracy: 0.608
# Inception Score: 4.817156036032195
#
# Epoch 140:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 56.14% and 0.685.
# Discriminator class accuracy and loss on real data is 64.02% and -6.371.
# Discriminator source accuracy and loss on fake data is 55.88% and 0.684.
# Discriminator class accuracy and loss on fake data is 98.00% and -0.979.
# Generator source accuracy and loss is 43.47% and 0.756.
# Generator class accuracy and loss is 98.14% and -0.980.
# Resnet Accuracy: 0.5994
# Inception Score: 4.721750457397832
#
# Epoch 141:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 57.51% and 0.679.
# Discriminator class accuracy and loss on real data is 63.92% and -6.367.
# Discriminator source accuracy and loss on fake data is 56.15% and 0.683.
# Discriminator class accuracy and loss on fake data is 98.34% and -0.982.
# Generator source accuracy and loss is 43.71% and 0.753.
# Generator class accuracy and loss is 98.27% and -0.981.
# Resnet Accuracy: 0.5669
# Inception Score: 4.40570522534524
#
# Epoch 142:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 56.70% and 0.682.
# Discriminator class accuracy and loss on real data is 64.04% and -6.382.
# Discriminator source accuracy and loss on fake data is 55.60% and 0.684.
# Discriminator class accuracy and loss on fake data is 98.12% and -0.980.
# Generator source accuracy and loss is 44.37% and 0.750.
# Generator class accuracy and loss is 98.21% and -0.980.
# Resnet Accuracy: 0.5698
# Inception Score: 4.412374334761094
#
# Epoch 143:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 56.94% and 0.681.
# Discriminator class accuracy and loss on real data is 64.16% and -6.386.
# Discriminator source accuracy and loss on fake data is 55.98% and 0.684.
# Discriminator class accuracy and loss on fake data is 98.24% and -0.981.
# Generator source accuracy and loss is 43.63% and 0.752.
# Generator class accuracy and loss is 98.08% and -0.979.
# Resnet Accuracy: 0.6097
# Inception Score: 4.843655480623675
#
# Epoch 144:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 57.09% and 0.682.
# Discriminator class accuracy and loss on real data is 63.86% and -6.356.
# Discriminator source accuracy and loss on fake data is 55.89% and 0.682.
# Discriminator class accuracy and loss on fake data is 98.25% and -0.981.
# Generator source accuracy and loss is 43.72% and 0.754.
# Generator class accuracy and loss is 98.18% and -0.980.
# Resnet Accuracy: 0.6275
# Inception Score: 5.001548822184532
#
# Epoch 145:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 56.88% and 0.681.
# Discriminator class accuracy and loss on real data is 64.33% and -6.405.
# Discriminator source accuracy and loss on fake data is 56.32% and 0.682.
# Discriminator class accuracy and loss on fake data is 98.15% and -0.980.
# Generator source accuracy and loss is 43.70% and 0.754.
# Generator class accuracy and loss is 98.20% and -0.980.
# Resnet Accuracy: 0.6266
# Inception Score: 4.838420021787033
#
# Epoch 146:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 57.09% and 0.681.
# Discriminator class accuracy and loss on real data is 64.17% and -6.393.
# Discriminator source accuracy and loss on fake data is 55.87% and 0.682.
# Discriminator class accuracy and loss on fake data is 98.32% and -0.982.
# Generator source accuracy and loss is 43.78% and 0.750.
# Generator class accuracy and loss is 98.39% and -0.982.
# Resnet Accuracy: 0.6322
# Inception Score: 4.919865840362384
#
# Epoch 147:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 57.30% and 0.680.
# Discriminator class accuracy and loss on real data is 64.38% and -6.413.
# Discriminator source accuracy and loss on fake data is 55.90% and 0.682.
# Discriminator class accuracy and loss on fake data is 97.86% and -0.977.
# Generator source accuracy and loss is 43.88% and 0.750.
# Generator class accuracy and loss is 97.93% and -0.978.
# Resnet Accuracy: 0.6116
# Inception Score: 4.751231468450266
#
# Epoch 148:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 56.75% and 0.682.
# Discriminator class accuracy and loss on real data is 63.96% and -6.374.
# Discriminator source accuracy and loss on fake data is 56.31% and 0.681.
# Discriminator class accuracy and loss on fake data is 98.05% and -0.979.
# Generator source accuracy and loss is 42.90% and 0.756.
# Generator class accuracy and loss is 98.20% and -0.981.
# Resnet Accuracy: 0.5954
# Inception Score: 4.547607947853049
#
# Epoch 149:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 56.51% and 0.682.
# Discriminator class accuracy and loss on real data is 64.49% and -6.424.
# Discriminator source accuracy and loss on fake data is 55.89% and 0.683.
# Discriminator class accuracy and loss on fake data is 98.28% and -0.981.
# Generator source accuracy and loss is 43.78% and 0.750.
# Generator class accuracy and loss is 98.21% and -0.981.
# Resnet Accuracy: 0.6163
# Inception Score: 4.842855096019227
#
# Epoch 150:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 56.96% and 0.681.
# Discriminator class accuracy and loss on real data is 64.51% and -6.428.
# Discriminator source accuracy and loss on fake data is 55.46% and 0.684.
# Discriminator class accuracy and loss on fake data is 98.42% and -0.982.
# Generator source accuracy and loss is 43.77% and 0.750.
# Generator class accuracy and loss is 98.31% and -0.982.
# Resnet Accuracy: 0.6
# Inception Score: 4.65636170459788
#
# Epoch 151:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 56.38% and 0.683.
# Discriminator class accuracy and loss on real data is 64.30% and -6.407.
# Discriminator source accuracy and loss on fake data is 55.74% and 0.684.
# Discriminator class accuracy and loss on fake data is 98.39% and -0.983.
# Generator source accuracy and loss is 44.31% and 0.748.
# Generator class accuracy and loss is 98.45% and -0.983.
# Resnet Accuracy: 0.5799
# Inception Score: 4.432558832283997
#
# Epoch 152:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 56.93% and 0.682.
# Discriminator class accuracy and loss on real data is 64.60% and -6.439.
# Discriminator source accuracy and loss on fake data is 55.93% and 0.682.
# Discriminator class accuracy and loss on fake data is 98.28% and -0.982.
# Generator source accuracy and loss is 44.16% and 0.747.
# Generator class accuracy and loss is 98.35% and -0.982.
# Resnet Accuracy: 0.5742
# Inception Score: 4.327653095948235
#
# Epoch 153:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 56.46% and 0.683.
# Discriminator class accuracy and loss on real data is 64.60% and -6.435.
# Discriminator source accuracy and loss on fake data is 55.56% and 0.684.
# Discriminator class accuracy and loss on fake data is 98.34% and -0.982.
# Generator source accuracy and loss is 43.88% and 0.747.
# Generator class accuracy and loss is 98.27% and -0.981.
# Resnet Accuracy: 0.569
# Inception Score: 4.30858332731331
#
# Epoch 154:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 56.35% and 0.684.
# Discriminator class accuracy and loss on real data is 64.89% and -6.462.
# Discriminator source accuracy and loss on fake data is 56.09% and 0.682.
# Discriminator class accuracy and loss on fake data is 98.34% and -0.982.
# Generator source accuracy and loss is 43.47% and 0.750.
# Generator class accuracy and loss is 98.40% and -0.982.
# Resnet Accuracy: 0.5543
# Inception Score: 4.314814936024296
#
# Epoch 155:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 55.81% and 0.685.
# Discriminator class accuracy and loss on real data is 64.39% and -6.414.
# Discriminator source accuracy and loss on fake data is 55.54% and 0.685.
# Discriminator class accuracy and loss on fake data is 98.22% and -0.981.
# Generator source accuracy and loss is 44.40% and 0.745.
# Generator class accuracy and loss is 98.35% and -0.982.
# Resnet Accuracy: 0.5683
# Inception Score: 4.451809373501011
#
# Epoch 156:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 56.68% and 0.683.
# Discriminator class accuracy and loss on real data is 64.60% and -6.432.
# Discriminator source accuracy and loss on fake data is 55.50% and 0.683.
# Discriminator class accuracy and loss on fake data is 98.40% and -0.983.
# Generator source accuracy and loss is 44.20% and 0.745.
# Generator class accuracy and loss is 98.38% and -0.982.
# Resnet Accuracy: 0.5705
# Inception Score: 4.423754267209853
#
# Epoch 157:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 56.20% and 0.684.
# Discriminator class accuracy and loss on real data is 65.03% and -6.471.
# Discriminator source accuracy and loss on fake data is 55.45% and 0.685.
# Discriminator class accuracy and loss on fake data is 98.37% and -0.982.
# Generator source accuracy and loss is 43.97% and 0.747.
# Generator class accuracy and loss is 98.29% and -0.982.
# Resnet Accuracy: 0.575
# Inception Score: 4.492130890215089
#
# Epoch 158:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 56.13% and 0.684.
# Discriminator class accuracy and loss on real data is 64.79% and -6.457.
# Discriminator source accuracy and loss on fake data is 55.79% and 0.683.
# Discriminator class accuracy and loss on fake data is 98.34% and -0.982.
# Generator source accuracy and loss is 43.75% and 0.748.
# Generator class accuracy and loss is 98.34% and -0.982.
# Resnet Accuracy: 0.5797
# Inception Score: 4.4915964500884265
#
# Epoch 159:
# Batch Index: 0
# Batch Index: 100
# Batch Index: 200
# Batch Index: 300
# Batch Index: 400
# Discriminator source accuracy and loss on real data is 56.26% and 0.683.
# Discriminator class accuracy and loss on real data is 64.80% and -6.455.
# Discriminator source accuracy and loss on fake data is 55.53% and 0.684.
# Discriminator class accuracy and loss on fake data is 98.35% and -0.982.
# Generator source accuracy and loss is 43.50% and 0.748.
# Generator class accuracy and loss is 98.41% and -0.983.
# Resnet Accuracy: 0.5569
# Inception Score: 4.3803893735434425
